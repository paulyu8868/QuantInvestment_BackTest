# %% [markdown]
# <a href="https://colab.research.google.com/github/paulyu8868/test/blob/main/%EC%B9%A8%EB%AA%B0%EB%B0%A9%EC%A7%80%EB%B2%95v1_2(%EC%88%98%EB%9F%89%EA%B3%84%EC%82%B0%EC%88%98%EC%A0%95).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from dataclasses import dataclass


import warnings
# 모든 FutureWarning 무시
warnings.filterwarnings('ignore', category=FutureWarning)
# UserWarning도 무시
warnings.filterwarnings('ignore', category=UserWarning)

# %%
#기간별 주가 데이터 불러오기
def get_data(ticker, start, end):
    df = yf.download(ticker, start=start, end=end)
    df = df.drop(columns=['Volume', 'Adj Close'])
    df.index = df.index.date

    # 호가 단위 0.01$ 적용
    for col in ['Open', 'High', 'Low', 'Close']: # 시가,고가,저가,종가
        df[col] = df[col].map(round_half_up_to_two)

    # 등락율 계산
    df['Return'] = df['Close'].pct_change()
    df['Return'] = df['Return'].map(pointTopercent)
    #df['Return'] = df['Return'].map(round_half_up_to_two)

    return df

# %%
# 소수 셋째자리에서 반올림
def round_half_up_to_two(num):
    try:
        if isinstance(num, (float, int)):
            num_100 = num * 100
            if num_100 - int(num_100) >= 0.5:
                return (int(num_100) + 1) / 100
            else:
                return int(num_100) / 100
        else:
            return num
    except:
        return num

# 퍼센트로 변환
def pointTopercent(num):
    return round_half_up_to_two(num*100)

# %%
def calculate_mdd(equity_curve):
    """MDD(Maximum Drawdown) 계산"""
    cummax = equity_curve.cummax()
    drawdown = (equity_curve - cummax) / cummax * 100
    mdd = drawdown.min()
    return mdd

# %%
# 침몰방지법 매매로직
def infinite_buy_simulation(df, df_res, initial_funds, buy_portion, start_idx, simulation_period):
    funds = initial_funds # 초기 자금
    one_buy_amount = initial_funds / buy_portion # 회차별 매수금액
    holdings = 0 # 보유 주식 수
    buy_records = []  # 각 매수 건을 저장하여 관리 (개별 매도 관리)
    trade_history = []  # 매도 기록 저장
    trade_id = 1  # 매수 회차별 ID (매수 구분)

    T=0 # T값 = 보유 회차 수

    # 날짜별 거래기록 데이터 프레임
    df_res = pd.DataFrame(index=range(start_idx, start_idx + simulation_period + 1),
                         columns=['날짜', '시가', '고가', '종가', '등락율',
                                'LOC 매수', '수익 실현 매도', 'MOC 손절',
                                '보유 주식 수', '예수금', '총 평가액', '수익율(%)'])

    # 시작일 - 종료일 시뮬레이션 진행
    for i in range(start_idx, start_idx + simulation_period + 1):
        # 데이터 시리즈로 가져오기
        current_date = df.index[i]
        open_price = float(df['Open'].iloc[i]) #시가
        high_price = float(df['High'].iloc[i]) #고가
        close_price = float(df['Close'].iloc[i]) #종가
        return_val = float(df['Return'].iloc[i]) #등락율
        prev_price = float(df['Close'].iloc[i-1]) if i > 0 else close_price #전날 종가



        # 오늘 데이터
        df_res.at[i, '날짜'] = current_date
        df_res.at[i, '시가'] = open_price
        df_res.at[i, '고가'] = high_price
        df_res.at[i, '종가'] = close_price
        df_res.at[i, '등락율'] = f"{round_half_up_to_two(return_val)}%"

        # 당일 종가
        price = close_price

        # 매수/매도 칼럼 초기화
        df_res.at[i, 'LOC 매수'] = 0
        df_res.at[i, '수익 실현 매도'] = 0
        df_res.at[i, 'MOC 손절'] = 0

        '''
        매매로직
        매수 : (5-maximumT)%
        매도 : (10.5-2*maximumT)%
        최대보유기간 : (30-3*maximumT)일
        maximumT = min(T,5)
        '''
        maximumT=min(T,5) # T값 최대 5까지 적용
        start_T=T
        loc_buy = (1.05-0.01*maximumT) # 매수 기준
        loc_sell = (1.105-0.02*maximumT) # 매도 기준
        # 매수 로직
        if price <= prev_price*loc_buy: # 매수 기준
            qty = int(one_buy_amount / (prev_price * loc_buy)) # 매수 주문 수량 => 매수 시도액 기준으로 계산
            if funds >= qty * price:
                holdings += qty
                funds -= qty * price
                T +=1 # 회차수 +=1
                buy_records.append({
                    'id': trade_id,
                    'buy_date': current_date,
                    'buy_price': price,
                    'quantity': qty,
                    'days': 0,
                    'type': 'LOC 매수'
                })
                df_res.at[i, 'LOC 매수'] = qty
                trade_id += 1

        # 매도 로직
        if holdings > 0:
            new_buy_records = []  # 매도되지 않은 매수 건을 저장할 새 리스트
            total_sell = 0  # 당일 총 매도 수량

            for record in buy_records: # 보유 주식 순회
                record['days'] += 1  # 보유일 count
                # 각 매수 건별 매도 목표가
                sell_price = record['buy_price'] * loc_sell # 매도 기준

                if price >= sell_price:  # 수익 실현 매도 조건 충족
                    funds += record['quantity'] * price
                    total_sell += record['quantity']
                    holdings -= record['quantity']
                    T-=1 # 회차수 -=1

                    # 거래 기록 저장
                    trade_history.append({
                        '회차': record['id'],
                        '매수일': record['buy_date'],
                        '매수가': record['buy_price'],
                        '매수수량': record['quantity'],
                        '매도일': current_date,
                        '매도가': price,
                        '매도수량': record['quantity'],
                        '보유기간': record['days'],
                        '수익률(%)': round_half_up_to_two((price/record['buy_price'] - 1) * 100),
                        '적용 모드': "투자모드" if (maximumT)<5 else "회복모드",
                        '적용 T':start_T
                    })
                elif record['days'] >= (30-maximumT*3):  # 최대 보유일수 경과시 MOC 매도
                    funds += record['quantity'] * price
                    df_res.at[i, 'MOC 손절'] = record['quantity']
                    holdings -= record['quantity']
                    T-=1 # 회차수 -=1
                    # 손절 거래 기록 저장
                    trade_history.append({
                        '회차': record['id'],
                        '매수일': record['buy_date'],
                        '매수가': record['buy_price'],
                        '매수수량': record['quantity'],
                        '매도일': current_date,
                        '매도가': price,
                        '매도수량': record['quantity'],
                        '보유기간': record['days'],
                        '수익률(%)': (price/record['buy_price'] - 1) * 100,
                        '적용 모드': "투자모드" if (maximumT)<5 else "회복모드",
                        '적용 T':start_T
                    })
                else:
                    new_buy_records.append(record)

            if total_sell > 0:
                df_res.at[i, '수익 실현 매도'] = total_sell

            buy_records = new_buy_records

        # 포트폴리오 상태 저장
        df_res.at[i, '보유 주식 수'] = holdings
        df_res.at[i, '예수금'] = funds
        df_res.at[i, '총 평가액'] = funds + (price * holdings)
        df_res.at[i, '수익율(%)'] = ((funds + (price * holdings)) / initial_funds - 1) * 100
        df_res.at[i, 'MDD'] = calculate_mdd(df_res['총 평가액'])
        df_res.at[i, 'T값'] = T
        df_res.at[i, '모드'] = "회복" if T>=5 else "투자"

    final_value = funds + (holdings * float(df['Close'].iloc[start_idx + simulation_period]))
    final_mdd = calculate_mdd(df_res['총 평가액'])
    return round_half_up_to_two((final_value / initial_funds - 1) * 100), df_res, final_value, pd.DataFrame(trade_history) , final_mdd

# %%
if __name__ == "__main__":
    start_date = '2018-01-01'
    end_date = '2020-12-31'
    initial_funds = 100000 # 초기 자금
    buy_portion = 10  # 회차 분할 수

    # 시작일 30일 전의 날짜
    start_date_dt = datetime.strptime(start_date,'%Y-%m-%d')
    start_date_before_30 = start_date_dt - timedelta(days=30)
    start_date_before_30 = start_date_before_30.strftime('%Y-%m-%d')

    # 종료일 다음 날 계산
    end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')
    next_day = end_date_dt + timedelta(days=1)
    end_day_next = next_day.strftime('%Y-%m-%d')

    # 30일 전 데이터부터 입력
    # ticker 값으로 종목 선택 가능 ex) TQQQ
    df = get_data(ticker='TQQQ', start=start_date_before_30, end=end_day_next)
    df_length = len(df) - len(get_data(ticker='TQQQ', start=start_date, end=end_day_next))

    df_res = pd.DataFrame(columns=['날짜', '시가', '고가', '종가', '등락율', 'LOC 매수', '수익 실현 매도', 'MOC 손절',
                                  '보유 주식 수', '예수금', '총 평가액', '수익율(%)', 'MDD','T값',"모드"])

    # 시뮬레이션 실행
    return_rate, df_res, final_value, df_trades ,final_mdd= infinite_buy_simulation(
        df, df_res, initial_funds, buy_portion, df_length, len(df)-1-df_length)

    # 매매 통계 출력
    print('\n' + '='*80)
    print("매매 통계")
    print('='*80)
    print(f"총 매매 횟수: {len(df_trades)} 회")
    print(f"평균 보유기간: {df_trades['보유기간'].mean():.1f} 일")
    print(f"평균 수익률: {df_trades['수익률(%)'].mean():.2f}%")
    win_rate = len(df_trades[df_trades['수익률(%)'] > 0]) / len(df_trades) * 100
    print(f"승률: {win_rate:.2f}%")

    print('\n' + '='*80)
    print(f"{start_date} ~ {end_date} 동안의 자산 변동 결과")
    print('='*80)
    print(f"최초 보유 금액: ${initial_funds:,.2f}")
    print(f"최종 보유 금액: ${final_value:,.2f}")
    print(f"원금 변화율: {return_rate}%")
    print(f"MDD : {final_mdd:.2f}%")
    print('='*80)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ================================================================================
# 매매 통계
# ================================================================================
# 총 매매 횟수: 487 회
# 평균 보유기간: 6.2 일
# 평균 수익률: 1.92%
# 승률: 87.68%
#
# ================================================================================
# 2018-01-01 ~ 2020-12-31 동안의 자산 변동 결과
# ================================================================================
# 최초 보유 금액: $100,000.00
# 최종 보유 금액: $189,203.36
# 원금 변화율: 89.2%
# MDD : -19.04%
# ================================================================================

# %%
# 날짜별 거래 현황 출력
print("\n[일별 거래 현황]")
df_res_style = df_res.style.format({
    '시가': '{:.2f}',
    '고가': '{:.2f}',
    '종가': '{:.2f}',
    'LOC 매수': '{:.0f}',
    '수익 실현 매도': '{:.0f}',
    'MOC 손절': '{:.0f}',
    '보유 주식 수': '{:.0f}',
    '예수금': '{:.2f}',
    '총 평가액': '{:.2f}',
    '수익율(%)': '{:.2f}',
    'MDD': '{:.2f}',
    'T값': '{:.0f}'
}).set_properties(**{'text-align': 'center'})
display(df_res_style)
# Out:
# [일별 거래 현황]
# <style type="text/css">
# #T_b7a51_row0_col0, #T_b7a51_row0_col1, #T_b7a51_row0_col2, #T_b7a51_row0_col3, #T_b7a51_row0_col4, #T_b7a51_row0_col5, #T_b7a51_row0_col6, #T_b7a51_row0_col7, #T_b7a51_row0_col8, #T_b7a51_row0_col9, #T_b7a51_row0_col10, #T_b7a51_row0_col11, #T_b7a51_row0_col12, #T_b7a51_row0_col13, #T_b7a51_row0_col14, #T_b7a51_row1_col0, #T_b7a51_row1_col1, #T_b7a51_row1_col2, #T_b7a51_row1_col3, #T_b7a51_row1_col4, #T_b7a51_row1_col5, #T_b7a51_row1_col6, #T_b7a51_row1_col7, #T_b7a51_row1_col8, #T_b7a51_row1_col9, #T_b7a51_row1_col10, #T_b7a51_row1_col11, #T_b7a51_row1_col12, #T_b7a51_row1_col13, #T_b7a51_row1_col14, #T_b7a51_row2_col0, #T_b7a51_row2_col1, #T_b7a51_row2_col2, #T_b7a51_row2_col3, #T_b7a51_row2_col4, #T_b7a51_row2_col5, #T_b7a51_row2_col6, #T_b7a51_row2_col7, #T_b7a51_row2_col8, #T_b7a51_row2_col9, #T_b7a51_row2_col10, #T_b7a51_row2_col11, #T_b7a51_row2_col12, #T_b7a51_row2_col13, #T_b7a51_row2_col14, #T_b7a51_row3_col0, #T_b7a51_row3_col1, #T_b7a51_row3_col2, #T_b7a51_row3_col3, #T_b7a51_row3_col4, #T_b7a51_row3_col5, #T_b7a51_row3_col6, #T_b7a51_row3_col7, #T_b7a51_row3_col8, #T_b7a51_row3_col9, #T_b7a51_row3_col10, #T_b7a51_row3_col11, #T_b7a51_row3_col12, #T_b7a51_row3_col13, #T_b7a51_row3_col14, #T_b7a51_row4_col0, #T_b7a51_row4_col1, #T_b7a51_row4_col2, #T_b7a51_row4_col3, #T_b7a51_row4_col4, #T_b7a51_row4_col5, #T_b7a51_row4_col6, #T_b7a51_row4_col7, #T_b7a51_row4_col8, #T_b7a51_row4_col9, #T_b7a51_row4_col10, #T_b7a51_row4_col11, #T_b7a51_row4_col12, #T_b7a51_row4_col13, #T_b7a51_row4_col14, #T_b7a51_row5_col0, #T_b7a51_row5_col1, #T_b7a51_row5_col2, #T_b7a51_row5_col3, #T_b7a51_row5_col4, #T_b7a51_row5_col5, #T_b7a51_row5_col6, #T_b7a51_row5_col7, #T_b7a51_row5_col8, #T_b7a51_row5_col9, #T_b7a51_row5_col10, #T_b7a51_row5_col11, #T_b7a51_row5_col12, #T_b7a51_row5_col13, #T_b7a51_row5_col14, #T_b7a51_row6_col0, #T_b7a51_row6_col1, #T_b7a51_row6_col2, #T_b7a51_row6_col3, #T_b7a51_row6_col4, #T_b7a51_row6_col5, #T_b7a51_row6_col6, #T_b7a51_row6_col7, #T_b7a51_row6_col8, #T_b7a51_row6_col9, #T_b7a51_row6_col10, #T_b7a51_row6_col11, #T_b7a51_row6_col12, #T_b7a51_row6_col13, #T_b7a51_row6_col14, #T_b7a51_row7_col0, #T_b7a51_row7_col1, #T_b7a51_row7_col2, #T_b7a51_row7_col3, #T_b7a51_row7_col4, #T_b7a51_row7_col5, #T_b7a51_row7_col6, #T_b7a51_row7_col7, #T_b7a51_row7_col8, #T_b7a51_row7_col9, #T_b7a51_row7_col10, #T_b7a51_row7_col11, #T_b7a51_row7_col12, #T_b7a51_row7_col13, #T_b7a51_row7_col14, #T_b7a51_row8_col0, #T_b7a51_row8_col1, #T_b7a51_row8_col2, #T_b7a51_row8_col3, #T_b7a51_row8_col4, #T_b7a51_row8_col5, #T_b7a51_row8_col6, #T_b7a51_row8_col7, #T_b7a51_row8_col8, #T_b7a51_row8_col9, #T_b7a51_row8_col10, #T_b7a51_row8_col11, #T_b7a51_row8_col12, #T_b7a51_row8_col13, #T_b7a51_row8_col14, #T_b7a51_row9_col0, #T_b7a51_row9_col1, #T_b7a51_row9_col2, #T_b7a51_row9_col3, #T_b7a51_row9_col4, #T_b7a51_row9_col5, #T_b7a51_row9_col6, #T_b7a51_row9_col7, #T_b7a51_row9_col8, #T_b7a51_row9_col9, #T_b7a51_row9_col10, #T_b7a51_row9_col11, #T_b7a51_row9_col12, #T_b7a51_row9_col13, #T_b7a51_row9_col14, #T_b7a51_row10_col0, #T_b7a51_row10_col1, #T_b7a51_row10_col2, #T_b7a51_row10_col3, #T_b7a51_row10_col4, #T_b7a51_row10_col5, #T_b7a51_row10_col6, #T_b7a51_row10_col7, #T_b7a51_row10_col8, #T_b7a51_row10_col9, #T_b7a51_row10_col10, #T_b7a51_row10_col11, #T_b7a51_row10_col12, #T_b7a51_row10_col13, #T_b7a51_row10_col14, #T_b7a51_row11_col0, #T_b7a51_row11_col1, #T_b7a51_row11_col2, #T_b7a51_row11_col3, #T_b7a51_row11_col4, #T_b7a51_row11_col5, #T_b7a51_row11_col6, #T_b7a51_row11_col7, #T_b7a51_row11_col8, #T_b7a51_row11_col9, #T_b7a51_row11_col10, #T_b7a51_row11_col11, #T_b7a51_row11_col12, #T_b7a51_row11_col13, #T_b7a51_row11_col14, #T_b7a51_row12_col0, #T_b7a51_row12_col1, #T_b7a51_row12_col2, #T_b7a51_row12_col3, #T_b7a51_row12_col4, #T_b7a51_row12_col5, #T_b7a51_row12_col6, #T_b7a51_row12_col7, #T_b7a51_row12_col8, #T_b7a51_row12_col9, #T_b7a51_row12_col10, #T_b7a51_row12_col11, #T_b7a51_row12_col12, #T_b7a51_row12_col13, #T_b7a51_row ...

# %%
# 모든 매매 로그 출력
if not df_trades.empty:
    print("\n[매매 기록]")
    df_trades_style = df_trades.style.format({
        '매수가': '{:.2f}',
        '매수수량': '{:.0f}',
        '매도가': '{:.2f}',
        '매도수량': '{:.0f}',
        '수익률(%)': '{:.2f}',
        '적용 모드': '{:}',
        '적용 T': '{:.0f}'
    }).set_properties(**{'text-align': 'center'})

    # 수익률에 따른 색상 적용
    def color_returns(val):
        color = 'red' if val < 0 else ('blue' if val > 0 else 'black')
        return f'color: {color}'
    def mode_color(val):
        color = 'green' if val=="회복모드" else'black'
        return f'color: {color}'

    df_trades_style = df_trades_style.map(color_returns, subset=['수익률(%)'])
    df_trades_style = df_trades_style.map(mode_color, subset=['적용 모드'])
    display(df_trades_style)

    # 매매 통계 출력
    print('\n' + '='*80)
    print("매매 통계")
    print('='*80)
    print(f"총 매매 횟수: {len(df_trades)} 회")
    print(f"평균 보유기간: {df_trades['보유기간'].mean():.1f} 일")
    print(f"평균 수익률: {df_trades['수익률(%)'].mean():.2f}%")
    win_rate = len(df_trades[df_trades['수익률(%)'] > 0]) / len(df_trades) * 100
    print(f"승률: {win_rate:.2f}%")

    print('\n' + '='*80)
    print(f"{start_date} ~ {end_date} 동안의 자산 변동 결과")
    print('='*80)
    print(f"최초 보유 금액: ${initial_funds:,.2f}")
    print(f"최종 보유 금액: ${final_value:,.2f}")
    print(f"원금 변화율: {return_rate}%")
    print('='*80)
# Out:
# [매매 기록]
# <style type="text/css">
# #T_2d9e0_row0_col0, #T_2d9e0_row0_col1, #T_2d9e0_row0_col2, #T_2d9e0_row0_col3, #T_2d9e0_row0_col4, #T_2d9e0_row0_col5, #T_2d9e0_row0_col6, #T_2d9e0_row0_col7, #T_2d9e0_row0_col10, #T_2d9e0_row1_col0, #T_2d9e0_row1_col1, #T_2d9e0_row1_col2, #T_2d9e0_row1_col3, #T_2d9e0_row1_col4, #T_2d9e0_row1_col5, #T_2d9e0_row1_col6, #T_2d9e0_row1_col7, #T_2d9e0_row1_col10, #T_2d9e0_row2_col0, #T_2d9e0_row2_col1, #T_2d9e0_row2_col2, #T_2d9e0_row2_col3, #T_2d9e0_row2_col4, #T_2d9e0_row2_col5, #T_2d9e0_row2_col6, #T_2d9e0_row2_col7, #T_2d9e0_row2_col10, #T_2d9e0_row3_col0, #T_2d9e0_row3_col1, #T_2d9e0_row3_col2, #T_2d9e0_row3_col3, #T_2d9e0_row3_col4, #T_2d9e0_row3_col5, #T_2d9e0_row3_col6, #T_2d9e0_row3_col7, #T_2d9e0_row3_col10, #T_2d9e0_row4_col0, #T_2d9e0_row4_col1, #T_2d9e0_row4_col2, #T_2d9e0_row4_col3, #T_2d9e0_row4_col4, #T_2d9e0_row4_col5, #T_2d9e0_row4_col6, #T_2d9e0_row4_col7, #T_2d9e0_row4_col10, #T_2d9e0_row5_col0, #T_2d9e0_row5_col1, #T_2d9e0_row5_col2, #T_2d9e0_row5_col3, #T_2d9e0_row5_col4, #T_2d9e0_row5_col5, #T_2d9e0_row5_col6, #T_2d9e0_row5_col7, #T_2d9e0_row5_col10, #T_2d9e0_row6_col0, #T_2d9e0_row6_col1, #T_2d9e0_row6_col2, #T_2d9e0_row6_col3, #T_2d9e0_row6_col4, #T_2d9e0_row6_col5, #T_2d9e0_row6_col6, #T_2d9e0_row6_col7, #T_2d9e0_row6_col10, #T_2d9e0_row7_col0, #T_2d9e0_row7_col1, #T_2d9e0_row7_col2, #T_2d9e0_row7_col3, #T_2d9e0_row7_col4, #T_2d9e0_row7_col5, #T_2d9e0_row7_col6, #T_2d9e0_row7_col7, #T_2d9e0_row7_col10, #T_2d9e0_row8_col0, #T_2d9e0_row8_col1, #T_2d9e0_row8_col2, #T_2d9e0_row8_col3, #T_2d9e0_row8_col4, #T_2d9e0_row8_col5, #T_2d9e0_row8_col6, #T_2d9e0_row8_col7, #T_2d9e0_row8_col10, #T_2d9e0_row9_col0, #T_2d9e0_row9_col1, #T_2d9e0_row9_col2, #T_2d9e0_row9_col3, #T_2d9e0_row9_col4, #T_2d9e0_row9_col5, #T_2d9e0_row9_col6, #T_2d9e0_row9_col7, #T_2d9e0_row9_col10, #T_2d9e0_row10_col0, #T_2d9e0_row10_col1, #T_2d9e0_row10_col2, #T_2d9e0_row10_col3, #T_2d9e0_row10_col4, #T_2d9e0_row10_col5, #T_2d9e0_row10_col6, #T_2d9e0_row10_col7, #T_2d9e0_row10_col10, #T_2d9e0_row11_col0, #T_2d9e0_row11_col1, #T_2d9e0_row11_col2, #T_2d9e0_row11_col3, #T_2d9e0_row11_col4, #T_2d9e0_row11_col5, #T_2d9e0_row11_col6, #T_2d9e0_row11_col7, #T_2d9e0_row11_col10, #T_2d9e0_row12_col0, #T_2d9e0_row12_col1, #T_2d9e0_row12_col2, #T_2d9e0_row12_col3, #T_2d9e0_row12_col4, #T_2d9e0_row12_col5, #T_2d9e0_row12_col6, #T_2d9e0_row12_col7, #T_2d9e0_row12_col10, #T_2d9e0_row13_col0, #T_2d9e0_row13_col1, #T_2d9e0_row13_col2, #T_2d9e0_row13_col3, #T_2d9e0_row13_col4, #T_2d9e0_row13_col5, #T_2d9e0_row13_col6, #T_2d9e0_row13_col7, #T_2d9e0_row13_col10, #T_2d9e0_row14_col0, #T_2d9e0_row14_col1, #T_2d9e0_row14_col2, #T_2d9e0_row14_col3, #T_2d9e0_row14_col4, #T_2d9e0_row14_col5, #T_2d9e0_row14_col6, #T_2d9e0_row14_col7, #T_2d9e0_row14_col10, #T_2d9e0_row15_col0, #T_2d9e0_row15_col1, #T_2d9e0_row15_col2, #T_2d9e0_row15_col3, #T_2d9e0_row15_col4, #T_2d9e0_row15_col5, #T_2d9e0_row15_col6, #T_2d9e0_row15_col7, #T_2d9e0_row15_col10, #T_2d9e0_row16_col0, #T_2d9e0_row16_col1, #T_2d9e0_row16_col2, #T_2d9e0_row16_col3, #T_2d9e0_row16_col4, #T_2d9e0_row16_col5, #T_2d9e0_row16_col6, #T_2d9e0_row16_col7, #T_2d9e0_row16_col10, #T_2d9e0_row17_col0, #T_2d9e0_row17_col1, #T_2d9e0_row17_col2, #T_2d9e0_row17_col3, #T_2d9e0_row17_col4, #T_2d9e0_row17_col5, #T_2d9e0_row17_col6, #T_2d9e0_row17_col7, #T_2d9e0_row17_col10, #T_2d9e0_row18_col0, #T_2d9e0_row18_col1, #T_2d9e0_row18_col2, #T_2d9e0_row18_col3, #T_2d9e0_row18_col4, #T_2d9e0_row18_col5, #T_2d9e0_row18_col6, #T_2d9e0_row18_col7, #T_2d9e0_row18_col10, #T_2d9e0_row19_col0, #T_2d9e0_row19_col1, #T_2d9e0_row19_col2, #T_2d9e0_row19_col3, #T_2d9e0_row19_col4, #T_2d9e0_row19_col5, #T_2d9e0_row19_col6, #T_2d9e0_row19_col7, #T_2d9e0_row19_col10, #T_2d9e0_row20_col0, #T_2d9e0_row20_col1, #T_2d9e0_row20_col2, #T_2d9e0_row20_col3, #T_2d9e0_row20_col4, #T_2d9e0_row20_col5, #T_2d9e0_row20_col6, #T_2d9e0_row20_col7, #T_2d9e0_row20_col10, #T_2d9e0_row21_col0, #T_2d9e0_row21_col1, #T_2d9e0_row21_col2, #T_2d9e0_row21_col3, #T_2d9e0_row21_c ...
# ================================================================================
# 매매 통계
# ================================================================================
# 총 매매 횟수: 1004 회
# 평균 보유기간: 6.5 일
# 평균 수익률: 1.74%
# 승률: 86.55%
#
# ================================================================================
# 2015-01-01 ~ 2020-12-31 동안의 자산 변동 결과
# ================================================================================
# 최초 보유 금액: $100,000.00
# 최종 보유 금액: $272,921.30
# 원금 변화율: 172.92%
# ================================================================================
