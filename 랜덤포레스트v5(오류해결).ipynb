# %% [markdown]
# <a href="https://colab.research.google.com/github/paulyu8868/test/blob/main/%EB%9E%9C%EB%8D%A4%ED%8F%AC%EB%A0%88%EC%8A%A4%ED%8A%B8v5(%EC%98%A4%EB%A5%98%ED%95%B4%EA%B2%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import warnings

# UserWarning 무시
warnings.filterwarnings("ignore", category=UserWarning)


def calculate_indicators(df):
    """향상된 기술적 지표 계산 - 인덱스 접근 수정"""
    df = df.copy()

    # ===== 1. 추세/모멘텀 지표 =====

    # 다양한 기간 이동평균과 이격도
    for period in [20, 50, 200]:
        # 이동평균 계산
        ma_values = df['Close'].rolling(window=period).mean()
        df[f'MA{period}'] = ma_values

        # 이격도 계산 (열 이름 확인 및 수정)
        if period in [50, 200]:  # 필요한 경우에만 생성
            temp_deviation = ((df['Close'] - ma_values) / ma_values * 100)
            df[f'MA{period}이격도'] = temp_deviation

    # MACD 계산
    temp_exp1 = df['Close'].ewm(span=12, adjust=False).mean()
    temp_exp2 = df['Close'].ewm(span=26, adjust=False).mean()
    temp_macd = temp_exp1 - temp_exp2
    df['MACD'] = temp_macd
    temp_signal = temp_macd.ewm(span=9, adjust=False).mean()
    df['Signal'] = temp_signal
    df['MACD_Hist'] = temp_macd - temp_signal

    # 다양한 기간 수익률
    for period in [5, 10, 20, 60]:
        temp_return = df['Close'].pct_change(period) * 100
        df[f'수익률_{period}'] = temp_return

    # ===== 2. 변동성 지표 =====

    # ATR
    temp_high_low = df['High'] - df['Low']
    temp_high_close = np.abs(df['High'] - df['Close'].shift())
    temp_low_close = np.abs(df['Low'] - df['Close'].shift())
    temp_ranges = pd.concat([temp_high_low, temp_high_close, temp_low_close], axis=1)
    temp_true_range = temp_ranges.max(axis=1)
    df['ATR'] = temp_true_range.rolling(window=14).mean()

    # Bollinger Bands 계산
    df['BB_Middle'] = df['Close'].rolling(window=20).mean()
    df['BB_Std'] = df['Close'].rolling(window=20).std()
    df['BB_Upper'] = df['BB_Middle'] + (df['BB_Std'] * 2)
    df['BB_Lower'] = df['BB_Middle'] - (df['BB_Std'] * 2)
    df['BB_Width'] = (df['BB_Upper'] - df['BB_Lower']).replace([np.inf, -np.inf], np.nan)

    # 변동성
    df['변동성_20'] = (df['Close'].rolling(window=20).std() / df['Close'] * 100)

    # ===== 3. 거래량 지표 =====

    # 거래량 증감률
    df['거래량_증감'] = df['Volume'].pct_change() * 100

    # 거래량 이동평균 대비
    df['거래량_MA20'] = df['Volume'].rolling(window=20).mean()
    temp_vol_ratio = (df['Volume'] / df['Volume'].rolling(window=20).mean())
    df['거래량_비율'] = temp_vol_ratio.replace([np.inf, -np.inf], np.nan)

    # OBV
    df['OBV'] = (np.sign(df['Close'].diff()) * df['Volume']).fillna(0).cumsum()

    # ===== 4. 가격 패턴 =====

    # 고가/저가 대비 현재가 위치
    for period in [20, 60]:
        temp_high = df['High'].rolling(window=period).max()
        temp_low = df['Low'].rolling(window=period).min()
        temp_position = ((df['Close'] - temp_low) / (temp_high - temp_low) * 100)
        df[f'가격위치_{period}'] = temp_position.replace([np.inf, -np.inf], np.nan)

    # 캔들 크기
    temp_candle_size = (df['High'] - df['Low']) / df['Close'] * 100
    df['캔들크기'] = temp_candle_size.replace([np.inf, -np.inf], np.nan)

    # 연속 상승/하락일수
    df['일간상승'] = np.where(df['Close'] > df['Close'].shift(1), 1, -1)
    temp_streak = df['일간상승'].groupby((df['일간상승'] != df['일간상승'].shift(1)).cumsum()).cumcount() + 1
    df['연속상승'] = temp_streak * df['일간상승']

    # RSI
    temp_delta = df['Close'].diff()
    temp_gain = (temp_delta.where(temp_delta > 0, 0)).rolling(window=14).mean()
    temp_loss = (-temp_delta.where(temp_delta < 0, 0)).rolling(window=14).mean()
    temp_rs = temp_gain / temp_loss
    df['RSI'] = 100 - (100 / (1 + temp_rs))

    # NaN 값 처리
    df = df.ffill().bfill()
    df = df.replace([np.inf, -np.inf], np.nan)
    df = df.ffill().bfill()

    return df

# %%
def get_data(ticker, start, end):
    """주가 데이터 불러오기 - 날짜 처리 최종 수정"""
    # 문자열 날짜를 datetime으로 변환
    start_dt = pd.to_datetime(start)
    end_dt = pd.to_datetime(end)

    # yfinance에서 데이터 가져오기
    df = yf.download(ticker, start=start_dt, end=end_dt)

    # 거래량이 0인 행 제거
    df = df[df['Volume'] > 0].copy()

    # 인덱스의 timezone 제거 및 문자열로 변환
    df.index = pd.to_datetime(df.index).tz_localize(None).strftime('%Y-%m-%d')

    # 호가 단위 0.01$ 적용
    price_cols = ['Open', 'High', 'Low', 'Close']
    for col in price_cols:
        df[col] = df[col].round(2)

    # 등락율 계산
    df['Return'] = df['Close'].pct_change() * 100
    df['Return'] = df['Return'].round(2)

    # NaN 값 처리
    df = df.ffill().bfill()

    return df

def create_training_features(df, df_trades, target_return=1.1):
    """향상된 학습 데이터 생성"""
    features_list = []

    for _, trade in df_trades.iterrows():
        # 매수일을 문자열로 변환하여 데이터프레임 인덱스와 비교
        buy_date = pd.to_datetime(trade['매수일']).strftime('%Y-%m-%d')

        # 날짜 존재 여부 확인
        if buy_date not in df.index:
            print(f"Error: {buy_date} not in data index")
            continue

        try:
            trade_data = df.loc[buy_date]

            features = {
                '회차': trade['회차'],
                'MACD': float(trade_data['MACD']),
                'MACD_Hist': float(trade_data['MACD_Hist']),
                'MA50이격도': float(trade_data['MA50이격도']),
                'MA200이격도': float(trade_data['MA200이격도']),
                '수익률_5': float(trade_data['수익률_5']),
                '수익률_60': float(trade_data['수익률_60']),
                'ATR': float(trade_data['ATR']),
                'BB_Width': float(trade_data['BB_Width']),
                '변동성_20': float(trade_data['변동성_20']),
                '거래량_증감': float(trade_data['거래량_증감']),
                '거래량_비율': float(trade_data['거래량_비율']),
                '가격위치_20': float(trade_data['가격위치_20']),
                '가격위치_60': float(trade_data['가격위치_60']),
                '캔들크기': float(trade_data['캔들크기']),
                '연속상승': float(trade_data['연속상승']),
                'RSI': float(trade_data['RSI']),
                '실제수익률': trade['수익률(%)'],
                'is_target_achieved': trade['수익률(%)'] >= (target_return - 1) * 100
            }

            features_list.append(features)

        except Exception as e:
            print(f"Error processing trade {trade['회차']}: {str(e)}")
            continue

    print("\n[디버깅] 생성된 features_list 길이:", len(features_list))
    return pd.DataFrame(features_list)




def analyze_feature_importance(model, feature_names):
    """특성 중요도 분석"""
    importance = pd.DataFrame({
        '특성': feature_names,
        '중요도(%)': model.feature_importances_ * 100
    }).sort_values('중요도(%)', ascending=False)

    return importance

def analyze_model_performance(model, X_validate_scaled, y_validate, probability_threshold=0.5):
    """모델 성능 분석"""
    # 예측 확률
    y_prob = model.predict_proba(X_validate_scaled)[:, 1]

    # threshold 기반 예측
    y_pred = (y_prob >= probability_threshold).astype(int)

    # 기본 메트릭
    metrics = {
        '정확도': accuracy_score(y_validate, y_pred),
        '정밀도': precision_score(y_validate, y_pred),
        '재현율': recall_score(y_validate, y_pred),
        'F1': f1_score(y_validate, y_pred)
    }

    # 확률 구간별 실제 성공률
    prob_analysis = []
    prob_bins = np.arange(0, 1.1, 0.1)

    for i in range(len(prob_bins)-1):
        mask = (y_prob >= prob_bins[i]) & (y_prob < prob_bins[i+1])
        if mask.sum() > 0:
            actual_rate = y_validate[mask].mean()
            count = mask.sum()
            prob_analysis.append({
                '확률구간': f"{prob_bins[i]:.1f}~{prob_bins[i+1]:.1f}",
                '거래수': count,
                '실제성공률': actual_rate
            })

    return metrics, pd.DataFrame(prob_analysis)

def infinite_buy_simulation(df, df_res, initial_funds, buy_portion, start_idx, simulation_period):
    """매매 시뮬레이션 - 날짜 처리 최종 수정"""
    # 기존 코드와 동일하게 유지하되 날짜 처리만 문자열로 통일
    funds = initial_funds
    one_buy_amount = initial_funds / buy_portion
    holdings = 0
    buy_records = []
    trade_history = []
    trade_id = 1

    df_res = pd.DataFrame(index=range(start_idx, start_idx + simulation_period + 1),
                         columns=['날짜', '시가', '고가', '종가', '등락율',
                                'LOC 매수', '수익 실현 매도', 'MOC 손절',
                                '보유 주식 수', '예수금', '총 평가액', '수익율(%)'])

    for i in range(start_idx, start_idx + simulation_period + 1):
        current_date = df.index[i]  # 이미 문자열 형식
        open_price = float(df['Open'].iloc[i])
        high_price = float(df['High'].iloc[i])
        close_price = float(df['Close'].iloc[i])
        return_val = float(df['Return'].iloc[i])
        prev_price = float(df['Close'].iloc[i-1]) if i > 0 else close_price

        df_res.at[i, '날짜'] = current_date  # 문자열 그대로 사용
        df_res.at[i, '시가'] = open_price
        df_res.at[i, '고가'] = high_price
        df_res.at[i, '종가'] = close_price
        df_res.at[i, '등락율'] = f"{return_val}%"

        price = close_price

        df_res.at[i, 'LOC 매수'] = 0
        df_res.at[i, '수익 실현 매도'] = 0
        df_res.at[i, 'MOC 손절'] = 0

        # 매수 로직
        if price <= prev_price*1.5:
            qty = int(one_buy_amount / price)
            if funds >= qty * price:
                holdings += qty
                funds -= qty * price
                buy_records.append({
                    'id': trade_id,
                    'buy_date': current_date,
                    'buy_price': price,
                    'quantity': qty,
                    'days': 0,
                    'type': 'LOC 매수'
                })
                df_res.at[i, 'LOC 매수'] = qty
                trade_id += 1

        # 매도 로직
        if holdings > 0:
            new_buy_records = []
            total_sell = 0

            for record in buy_records:
                record['days'] += 1
                sell_price = record['buy_price'] * 1.1

                if price >= sell_price:
                    funds += record['quantity'] * price
                    total_sell += record['quantity']
                    holdings -= record['quantity']
                    trade_history.append({
                        '회차': record['id'],
                        '매수일': record['buy_date'],
                        '매수가': record['buy_price'],
                        '매수수량': record['quantity'],
                        '매도일': current_date,
                        '매도가': price,
                        '매도수량': record['quantity'],
                        '보유기간': record['days'],
                        '수익률(%)': round((price/record['buy_price'] - 1) * 100, 2)
                    })
                elif record['days'] >= 30:
                    funds += record['quantity'] * price
                    df_res.at[i, 'MOC 손절'] = record['quantity']
                    holdings -= record['quantity']
                    trade_history.append({
                        '회차': record['id'],
                        '매수일': record['buy_date'],
                        '매수가': record['buy_price'],
                        '매수수량': record['quantity'],
                        '매도일': current_date,
                        '매도가': price,
                        '매도수량': record['quantity'],
                        '보유기간': record['days'],
                        '수익률(%)': round((price/record['buy_price'] - 1) * 100, 2)
                    })
                else:
                    new_buy_records.append(record)

            if total_sell > 0:
                df_res.at[i, '수익 실현 매도'] = total_sell

            buy_records = new_buy_records

        df_res.at[i, '보유 주식 수'] = holdings
        df_res.at[i, '예수금'] = round(funds, 2)
        df_res.at[i, '총 평가액'] = round(funds + (price * holdings), 2)
        df_res.at[i, '수익율(%)'] = round(((funds + (price * holdings)) / initial_funds - 1) * 100, 2)

    final_value = funds + (holdings * float(df['Close'].iloc[start_idx + simulation_period]))
    return round((final_value / initial_funds - 1) * 100, 2), df_res, final_value, pd.DataFrame(trade_history)


def ml_infinite_buy_simulation(df, df_res, initial_funds, buy_portion, start_idx, simulation_period,
                             model, scaler, prediction_threshold):
    """ML 기반 매매 시뮬레이션"""
    funds = initial_funds
    one_buy_amount = initial_funds / buy_portion
    holdings = 0
    buy_records = []
    trade_history = []
    trade_id = 1

    df_res = pd.DataFrame(index=range(start_idx, start_idx + simulation_period + 1),
                         columns=['날짜', '시가', '고가', '종가', '등락율',
                                'LOC 매수', '수익 실현 매도', 'MOC 손절',
                                '보유 주식 수', '예수금', '총 평가액', '수익율(%)',
                                'ML예측확률'])

    for i in range(start_idx, start_idx + simulation_period + 1):
        current_date = df.index[i]
        open_price = float(df['Open'].iloc[i])
        high_price = float(df['High'].iloc[i])
        close_price = float(df['Close'].iloc[i])
        return_val = float(df['Return'].iloc[i])
        prev_price = float(df['Close'].iloc[i-1]) if i > 0 else close_price

        df_res.at[i, '날짜'] = current_date
        df_res.at[i, '시가'] = open_price
        df_res.at[i, '고가'] = high_price
        df_res.at[i, '종가'] = close_price
        df_res.at[i, '등락율'] = f"{return_val}%"

        price = close_price

        df_res.at[i, 'LOC 매수'] = 0
        df_res.at[i, '수익 실현 매도'] = 0
        df_res.at[i, 'MOC 손절'] = 0

        # 매수 로직
        if price <= prev_price*1.5:
            # 현재 상태의 특성 계산
            current_data = df.iloc[i]
            # ml_infinite_buy_simulation 함수에서
            # '이격도_50' -> 'MA50이격도'로 수정
            features = [
                float(current_data['MACD']),
                float(current_data['MACD_Hist']),
                float(current_data['MA50이격도']),  # 수정된 부분
                float(current_data['MA200이격도']),
                float(current_data['수익률_5']),
                float(current_data['수익률_60']),
                float(current_data['ATR']),
                float(current_data['BB_Width']),
                float(current_data['변동성_20']),
                float(current_data['거래량_증감']),
                float(current_data['거래량_비율']),
                float(current_data['가격위치_20']),
                float(current_data['가격위치_60']),
                float(current_data['캔들크기']),
                float(current_data['연속상승']),
                float(current_data['RSI'])
            ]

            # 성공 확률 예측
            features_scaled = scaler.transform([features])
            success_prob = model.predict_proba(features_scaled)[0][1]
            df_res.at[i, 'ML예측확률'] = f"{success_prob:.1%}"

            # 예측 확률이 threshold를 넘을 때만 매수
            # 임의 수정 부분
            if success_prob >= prediction_threshold:
                qty = int(one_buy_amount / price)
                print(f'예측확률 : {success_prob}'f' >= {prediction_threshold}')
                if funds >= qty * price:
                    holdings += qty
                    funds -= qty * price
                    buy_records.append({
                        'id': trade_id,
                        'buy_date': current_date,
                        'buy_price': price,
                        'quantity': qty,
                        'days': 0,
                        'type': 'LOC 매수',
                        'pred_prob': success_prob
                    })
                    df_res.at[i, 'LOC 매수'] = qty
                    trade_id += 1

        # 매도 로직 (기존과   )
        if holdings > 0:
            new_buy_records = []
            total_sell = 0

            for record in buy_records:
                record['days'] += 1
                sell_price = record['buy_price'] * 1.1

                if price >= sell_price:
                    funds += record['quantity'] * price
                    total_sell += record['quantity']
                    holdings -= record['quantity']
                    trade_history.append({
                        '회차': record['id'],
                        '매수일': record['buy_date'],
                        '매수가': record['buy_price'],
                        '매수수량': record['quantity'],
                        '매도일': current_date,
                        '매도가': price,
                        '매도수량': record['quantity'],
                        '보유기간': record['days'],
                        '수익률(%)': round((price/record['buy_price'] - 1) * 100, 2),
                        '예측확률': record['pred_prob']
                    })
                elif record['days'] >= 30:
                    funds += record['quantity'] * price
                    df_res.at[i, 'MOC 손절'] = record['quantity']
                    holdings -= record['quantity']
                    trade_history.append({
                        '회차': record['id'],
                        '매수일': record['buy_date'],
                        '매수가': record['buy_price'],
                        '매수수량': record['quantity'],
                        '매도일': current_date,
                        '매도가': price,
                        '매도수량': record['quantity'],
                        '보유기간': record['days'],
                        '수익률(%)': round((price/record['buy_price'] - 1) * 100, 2),
                        '예측확률': record['pred_prob']
                    })
                else:
                    new_buy_records.append(record)

            if total_sell > 0:
                df_res.at[i, '수익 실현 매도'] = total_sell

            buy_records = new_buy_records

        df_res.at[i, '보유 주식 수'] = holdings
        df_res.at[i, '예수금'] = round(funds, 2)
        df_res.at[i, '총 평가액'] = round(funds + (price * holdings), 2)
        df_res.at[i, '수익율(%)'] = round(((funds + (price * holdings)) / initial_funds - 1) * 100, 2)

    final_value = funds + (holdings * float(df['Close'].iloc[start_idx + simulation_period]))
    return round((final_value / initial_funds - 1) * 100, 2), df_res, final_value, pd.DataFrame(trade_history)

# %%
if __name__ == "__main__":
    # 1. 초기 설정
    start_date = '2020-01-01'
    end_date = '2020-12-31'
    initial_funds = 100000
    buy_portion = 7
    ticker = 'TQQQ'




    print("=== 백테스트 시작 ===")
    print(f"종목: {ticker}")
    print(f"기간: {start_date} ~ {end_date}")
    print(f"초기자금: ${initial_funds:,}")
    print(f"분할 횟수: {buy_portion}")

    try:
        # 2. 데이터 준비 - 디버깅을 위한 출력 추가
        start_date_dt = pd.to_datetime(start_date)
        start_date_before_30 = (start_date_dt - pd.Timedelta(days=30)).strftime('%Y-%m-%d')
        end_date_dt = pd.to_datetime(end_date)
        next_day = (end_date_dt + pd.Timedelta(days=1)).strftime('%Y-%m-%d')

        print("\n[디버그] 날짜 정보:")
        print(f"원본 시작일: {start_date}")
        print(f"30일 전 시작일: {start_date_before_30}")
        print(f"원본 종료일: {end_date}")
        print(f"다음 날: {next_day}")

        print("\n데이터 준비 중...")
        df = get_data(ticker, start_date_before_30, next_day)
        print(f"\n[디버깅] 데이터프레임 정보:")
        print(f"인덱스 타입: {type(df.index)}")
        print(f"첫 날짜: {df.index[0]}, 타입: {type(df.index[0])}")
        print(f"마지막 날짜: {df.index[-1]}, 타입: {type(df.index[-1])}")

        # 지표 계산 및 열 이름 단일화
        df = calculate_indicators(df)
        df.columns = df.columns.get_level_values(0)  # MultiIndex를 단일 인덱스로 변환

        print("\n[디버깅] 변환된 열 목록:")
        print(df.columns)

        # 3. 기존 전략 백테스트
        actual_start_data = get_data(ticker, start_date, next_day)
        df_length = len(df) - len(actual_start_data)
        print(f"\n총 {len(df):,}개의 데이터 준비 완료")

        print("\n기존 전략 백테스트 수행 중...")
        baseline_return, baseline_df_res, baseline_final, baseline_trades = infinite_buy_simulation(
            df, pd.DataFrame(), initial_funds, buy_portion, df_length, len(df)-1-df_length)

        print("\n[디버깅] baseline_trades 정보:")
        print(baseline_trades.head())
        print("거래 데이터 수:", len(baseline_trades))


        print("\n기존 전략 결과:")
        print(f"최종 수익률: {baseline_return:.2f}%")
        print(f"최종 자산: ${baseline_final:,.2f}")
        print(f"총 거래 수: {len(baseline_trades)}")
        print(f"성공 거래 비율: {(baseline_trades['수익률(%)'] >= 0).mean():.2%}")

        # 4. ML 모델 준비
        print("\n머신러닝 모델 준비 중...")
        feature_columns = [
            'MACD', 'MACD_Hist', 'MA50이격도', 'MA200이격도',
            '수익률_5', '수익률_60', 'ATR', 'BB_Width',
            '변동성_20', '거래량_증감', '거래량_비율',
            '가격위치_20', '가격위치_60', '캔들크기',
            '연속상승', 'RSI'
        ]

        # 학습 데이터 생성
        df_features = create_training_features(df, baseline_trades)

        # df_features 생성 후 열 점검
        print("\n[디버그] df_features 열 목록:")
        print(df_features.columns)

        # 누락된 열 확인
        missing_columns = [col for col in feature_columns if col not in df_features.columns]
        if missing_columns:
            print(f"\n누락된 열: {missing_columns}")


        # 학습/검증 데이터 분할
        train_size = int(len(df_features) * 0.7)
        df_train = df_features.iloc[:train_size]
        df_validate = df_features.iloc[train_size:]

        X_train = df_train[feature_columns]
        y_train = df_train['is_target_achieved']
        X_validate = df_validate[feature_columns]
        y_validate = df_validate['is_target_achieved']

        # 스케일링
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_validate_scaled = scaler.transform(X_validate)

        # 모델 학습
        model = RandomForestClassifier(n_estimators=200, max_depth=5, random_state=42)
        model.fit(X_train_scaled, y_train)

        # 5. 모델 성능 분석
        print("\n모델 성능 분석 중...")
        metrics, prob_analysis = analyze_model_performance(
            model, X_validate_scaled, y_validate)

        print("\n[검증 데이터 성능]")
        for metric, value in metrics.items():
            print(f"{metric}: {value:.2%}")

        print("\n[확률 구간별 실제 성공률]")
        print(prob_analysis)

        # 6. 특성 중요도 분석
        importance = analyze_feature_importance(model, feature_columns)
        print("\n[특성 중요도]")
        print(importance)

        # 7. ML 기반 전략 백테스트
        print("\nML 기반 전략 백테스트 수행 중...")
        prediction_threshold = 0.75
        ml_return, ml_df_res, ml_final, ml_trades = ml_infinite_buy_simulation(
            df, pd.DataFrame(), initial_funds, buy_portion, df_length, len(df)-1-df_length,
            model, scaler, prediction_threshold)

        # 8. 최종 결과 비교
        print("\n=== 최종 결과 비교 ===")
        print("\n[기존 전략]")
        print(f"최종 수익률: {baseline_return:.2f}%")
        print(f"최종 자산: ${baseline_final:,.2f}")
        print(f"총 거래 수: {len(baseline_trades)}")
        print(f"성공 거래 비율: {(baseline_trades['수익률(%)'] >= 0).mean():.2%}")

        print("\n[ML 기반 전략]")
        print(f"최종 수익률: {ml_return:.2f}%")
        print(f"최종 자산: ${ml_final:,.2f}")
        print(f"총 거래 수: {len(ml_trades)}")
        print(f"성공 거래 비율: {(ml_trades['수익률(%)'] >= 0).mean():.2%}")

        improvement = ml_return - baseline_return
        print(f"\n수익률 개선: {improvement:.2f}%p")

    except Exception as e:
        print(f"오류 발생: {str(e)}")
        import traceback
        print("\n[디버그] 상세 오류:")
        print(traceback.format_exc())
# Out:
# [*********************100%***********************]  1 of 1 completed
# === 백테스트 시작 ===
# 종목: TQQQ
# 기간: 2020-01-01 ~ 2020-12-31
# 초기자금: $100,000
# 분할 횟수: 7
#
# [디버그] 날짜 정보:
# 원본 시작일: 2020-01-01
# 30일 전 시작일: 2019-12-02
# 원본 종료일: 2020-12-31
# 다음 날: 2021-01-01
#
# 데이터 준비 중...
# [디버깅] 데이터프레임 정보:
# 인덱스 타입: <class 'pandas.core.indexes.base.Index'>
# 첫 날짜: 2019-12-02, 타입: <class 'str'>
# 마지막 날짜: 2020-12-31, 타입: <class 'str'>
# [*********************100%***********************]  1 of 1 completed
# [디버깅] 변환된 열 목록:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'Return', 'MA20',
#        'MA50', 'MA50이격도', 'MA200', 'MA200이격도', 'MACD', 'Signal', 'MACD_Hist',
#        '수익률_5', '수익률_10', '수익률_20', '수익률_60', 'ATR', 'BB_Middle', 'BB_Std',
#        'BB_Upper', 'BB_Lower', 'BB_Width', '변동성_20', '거래량_증감', '거래량_MA20',
#        '거래량_비율', 'OBV', '가격위치_20', '가격위치_60', '캔들크기', '일간상승', '연속상승', 'RSI'],
#       dtype='object', name='Price')
#
# 총 274개의 데이터 준비 완료
#
# 기존 전략 백테스트 수행 중...
# [디버깅] baseline_trades 정보:
#    회차         매수일    매수가  매수수량         매도일    매도가  매도수량  보유기간  수익률(%)
# 0   2  2020-01-03  22.09   646  2020-01-16  24.61   646    10   11.41
# 1   3  2020-01-06  22.51   634  2020-01-17  24.98   634    10   10.97
# 2   4  2020-01-07  22.49   635  2020-01-17  24.98   635     9   11.07
# 3   1  2020-01-02  22.71   629  2020-01-22  25.13   629    14   10.66
# 4   5  2020-01-08  23.00   621  2020-01-23  25.36   621    11   10.26
# 거래 데이터 수: 121
#
# 기존 전략 결과:
# 최종 수익률: 112.25%
# 최종 자산: $212,248.72
# 총 거래 수: 121
# 성공 거래 비율: 87.60%
#
# 머신러닝 모델 준비 중...
#
# [디버깅] 생성된 features_list 길이: 121
#
# [디버그] df_features 열 목록:
# Index(['회차', 'MACD', 'MACD_Hist', 'MA50이격도', 'MA200이격도', '수익률_5', '수익률_60',
#        'ATR', 'BB_Width', '변동성_20', '거래량_증감', '거래량_비율', '가격위치_20', '가격위치_60',
#        '캔들크기', '연속상승', 'RSI', '실제수익률', 'is_target_achieved'],
#       dtype='object')
#
# 모델 성능 분석 중...
#
# [검증 데이터 성능]
# 정확도: 72.97%
# 정밀도: 72.97%
# 재현율: 100.00%
# F1: 84.38%
#
# [확률 구간별 실제 성공률]
#       확률구간  거래수     실제성공률
# 0  0.8~0.9    4  1.000000
# 1  0.9~1.0   28  0.678571
#
# [특성 중요도]
#            특성     중요도(%)
# 9      거래량_증감  14.737812
# 12    가격위치_60  14.275717
# 7    BB_Width  10.741209
# 0        MACD   8.942208
# 13       캔들크기   8.940337
# 6         ATR   8.223498
# 10     거래량_비율   5.865897
# 1   MACD_Hist   5.651704
# 8      변동성_20   4.764793
# 15        RSI   3.985033
# 2     MA50이격도   3.685346
# 4       수익률_5   3.552242
# 11    가격위치_20   2.835528
# 5      수익률_60   2.646695
# 14       연속상승   1.151983
# 3    MA200이격도   0.000000
#
# ML 기반 전략 백테스트 수행 중...
# 예측확률 : 0.9115476190476192 >= 0.75
# 예측확률 : 0.9922368421052632 >= 0.75
# 예측확률 : 0.9922368421052632 >= 0.75
# 예측확률 : 0.9647368421052631 >= 0.75
# 예측확률 : 0.9697368421052631 >= 0.75
# 예측확률 : 0.9922368421052632 >= 0.75
# 예측확률 : 0.9797368421052631 >= 0.75
# 예측확률 : 0.9098809523809525 >= 0.75
# 예측확률 : 0.9214035087719299 >= 0.75
# 예측확률 : 0.9772368421052632 >= 0.75
# 예측확률 : 0.8775 >= 0.75
# 예측확률 : 0.9296177944862155 >= 0.75
# 예측확률 : 0.9322368421052631 >= 0.75
# 예측확률 : 0.9897368421052631 >= 0.75
# 예측확률 : 0.9797368421052631 >= 0.75
# 예측확률 : 0.9647368421052631 >= 0.75
# 예측확률 : 0.9247368421052632 >= 0.75
# 예측확률 : 0.9222368421052631 >= 0.75
# 예측확률 : 0.8397368421052631 >= 0.75
# 예측확률 : 0.8522368421052632 >= 0.75
# 예측확률 : 0.8022368421052631 >= 0.75
# 예측확률 : 0.7597368421052632 >= 0.75
# 예측확률 : 0.8247368421052631 >= 0.75
# 예측확률 : 0.75875 >= 0.75
# 예측확률 : 0.97 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.97125 >= 0.75
# 예측확률 : 0.905 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.97 >= 0.75
# 예측확률 : 0.975 >= 0.75
# 예측확률 : 0.98 >= 0.75
# 예측확률 : 0.975 >= 0.75
# 예측확률 : 0.965 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.9948809523809524 >= 0.75
# 예측확률 : 0.9898809523809524 >= 0.75
# 예측확률 : 0.9982142857142857 >= 0.75
# 예측확률 : 0.9248809523809524 >= 0.75
# 예측확률 : 0.9548809523809524 >= 0.75
# 예측확률 : 0.9298809523809524 >= 0.75
# 예측확률 : 0.9848809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9798809523809524 >= 0.75
# 예측확률 : 0.9930627705627706 >= 0.75
# 예측확률 : 0.9880627705627706 >= 0.75
# 예측확률 : 0.9963961038961038 >= 0.75
# 예측확률 : 0.9980627705627705 >= 0.75
# 예측확률 : 0.9530627705627706 >= 0.75
# 예측확률 : 0.9894642857142857 >= 0.75
# 예측확률 : 0.84 >= 0.75
# 예측확률 : 0.9826461038961039 >= 0.75
# 예측확률 : 0.9680627705627706 >= 0.75
# 예측확률 : 0.8509794372294373 >= 0.75
# 예측확률 : 0.9543127705627705 >= 0.75
# 예측확률 : 0.9780627705627706 >= 0.75
# 예측확률 : 0.9730627705627706 >= 0.75
# 예측확률 : 0.9948809523809524 >= 0.75
# 예측확률 : 0.81 >= 0.75
# 예측확률 : 0.9523809523809524 >= 0.75
# 예측확률 : 0.9486309523809524 >= 0.75
# 예측확률 : 0.9127976190476191 >= 0.75
# 예측확률 : 0.9686309523809524 >= 0.75
# 예측확률 : 0.9886309523809524 >= 0.75
# 예측확률 : 0.9786309523809524 >= 0.75
# 예측확률 : 0.97625 >= 0.75
# 예측확률 : 0.975 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.99375 >= 0.75
# 예측확률 : 0.9948809523809524 >= 0.75
# 예측확률 : 0.9986309523809525 >= 0.75
# 예측확률 : 0.835 >= 0.75
# 예측확률 : 0.98625 >= 0.75
# 예측확률 : 0.96125 >= 0.75
# 예측확률 : 0.985 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.875 >= 0.75
# 예측확률 : 0.97375 >= 0.75
# 예측확률 : 0.9574868421052632 >= 0.75
# 예측확률 : 0.9984868421052632 >= 0.75
# 예측확률 : 0.9834868421052632 >= 0.75
# 예측확률 : 0.9746177944862155 >= 0.75
# 예측확률 : 0.9533677944862156 >= 0.75
# 예측확률 : 0.9646177944862155 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.98 >= 0.75
# 예측확률 : 0.985 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.98625 >= 0.75
# 예측확률 : 0.9940000000000001 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.985 >= 0.75
# 예측확률 : 0.975 >= 0.75
# 예측확률 : 0.975 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.9938809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9948809523809524 >= 0.75
# 예측확률 : 0.9961309523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9948809523809524 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.99625 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.965 >= 0.75
# 예측확률 : 0.935 >= 0.75
# 예측확률 : 0.895 >= 0.75
# 예측확률 : 0.825 >= 0.75
# 예측확률 : 0.9690000000000001 >= 0.75
# 예측확률 : 0.924 >= 0.75
# 예측확률 : 0.9888809523809524 >= 0.75
# 예측확률 : 0.9888809523809524 >= 0.75
# 예측확률 : 0.9990000000000001 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.9940000000000001 >= 0.75
# 예측확률 : 0.9990000000000001 >= 0.75
# 예측확률 : 0.9923333333333333 >= 0.75
# 예측확률 : 0.8 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.98625 >= 0.75
# 예측확률 : 0.9798809523809524 >= 0.75
# 예측확률 : 0.9832142857142857 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9183333333333333 >= 0.75
# 예측확률 : 0.9798809523809524 >= 0.75
# 예측확률 : 0.9798809523809524 >= 0.75
# 예측확률 : 0.9798809523809524 >= 0.75
# 예측확률 : 0.9911309523809524 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.99125 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.9833333333333333 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.99625 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.99625 >= 0.75
# 예측확률 : 0.985 >= 0.75
# 예측확률 : 0.99 >= 0.75
# 예측확률 : 0.9833333333333333 >= 0.75
# 예측확률 : 0.955 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.9882142857142857 >= 0.75
# 예측확률 : 0.9811309523809524 >= 0.75
# 예측확률 : 0.855 >= 0.75
# 예측확률 : 0.9898809523809524 >= 0.75
# 예측확률 : 0.87 >= 0.75
# 예측확률 : 0.8915476190476191 >= 0.75
# 예측확률 : 0.9648809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 1.0 >= 0.75
# 예측확률 : 0.9783333333333333 >= 0.75
# 예측확률 : 0.99625 >= 0.75
# 예측확률 : 0.9683333333333333 >= 0.75
# 예측확률 : 0.9595833333333332 >= 0.75
# 예측확률 : 0.985 >= 0.75
# 예측확률 : 0.9645833333333332 >= 0.75
# 예측확률 : 0.925 >= 0.75
# 예측확률 : 0.965 >= 0.75
# 예측확률 : 0.995 >= 0.75
# 예측확률 : 0.9833333333333333 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9998809523809524 >= 0.75
# 예측확률 : 0.9898809523809524 >= 0.75
# 예측확률 : 0.9898809523809524 >= 0.75
# 예측확률 : 0.9898809523809524 >= 0.75
# 예측확률 : 0.9798809523809524 >= 0.75
# 예측확률 : 0.9848809523809524 >= 0.75
# 예측확률 : 0.8880627705627705 >= 0.75
# 예측확률 : 0.9748809523809524 >= 0.75
# 예측확률 : 0.9730627705627706 >= 0.75
# 예측확률 : 0.9347294372294372 >= 0.75
# 예측확률 : 0.9827651515151514 >= 0.75
# 예측확률 : 0.9798809523809524 >= 0.75
# 예측확률 : 0.8815476190476191 >= 0.75
# 예측확률 : 0.8398809523809524 >= 0.75
# 예측확률 : 0.8230627705627706 >= 0.75
# 예측확률 : 0.9638809523809525 >= 0.75
# 예측확률 : 0.9738809523809525 >= 0.75
# 예측확률 : 0.8722142857142857 >= 0.75
# 예측확률 : 0.7988809523809525 >= 0.75
# 예측확률 : 0.8048809523809524 >= 0.75
# 예측확률 : 0.9348809523809524 >= 0.75
# 예측확률 : 0.9461309523809525 >= 0.75
# 예측확률 : 0.985 >= 0.75
# 예측확률 : 0.9623333333333334 >= 0.75
# 예측확률 : 0.9623333333333334 >= 0.75
# 예측확률 : 0.9573333333333334 >= 0.75
# 예측확률 : 0.9623333333333334 >= 0.75
# 예측확률 : 0.9123333333333333 >= 0.75
# 예측확률 : 0.9840000000000001 >= 0.75
# 예측확률 : 0.9740000000000001 >= 0.75
# 예측확률 : 0.9640000000000001 >= 0.75
# 예측확률 : 0.8873333333333333 >= 0.75
# 예측확률 : 0.879 >= 0.75
# 예측확률 : 0.919 >= 0.75
# 예측확률 : 0.8740000000000001 >= 0.75
# 예측확률 : 0.8723333333333333 >= 0.75
#
# === 최종 결과 비교 ===
#
# [기존 전략]
# 최종 수익률: 112.25%
# 최종 자산: $212,248.72
# 총 거래 수: 121
# 성공 거래 비율: 87.60%
#
# [ML 기반 전략]
# 최종 수익률: 286.32%
# 최종 자산: $386,318.74
# 총 거래 수: 185
# 성공 거래 비율: 93.51%
#
# 수익률 개선: 174.07%p

# %%
# Out:
# === 백테스트 시작 ===
# 종목: TQQQ
# 기간: 2011-01-01 ~ 2024-10-31
# 초기자금: $100,000
# 분할 횟수: 30
#
# [디버그] 날짜 정보:
# 원본 시작일: 2011-01-01
# 30일 전 시작일: 2010-12-02
# 원본 종료일: 2024-10-31
# 다음 날: 2024-11-01
#
# 데이터 준비 중...
# [*********************100%***********************]  1 of 1 completed
# [디버그] 데이터프레임 정보:
# 인덱스 타입: <class 'pandas.core.indexes.base.Index'>
# 첫 날짜: 2010-12-02, 타입: <class 'str'>
# 마지막 날짜: 2024-10-31, 타입: <class 'str'>
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-5-c070036ad75d>:18: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   open_price = float(df['Open'].iloc[i])
# <ipython-input-5-c070036ad75d>:19: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   high_price = float(df['High'].iloc[i])
# <ipython-input-5-c070036ad75d>:20: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   close_price = float(df['Close'].iloc[i])
# <ipython-input-5-c070036ad75d>:22: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   prev_price = float(df['Close'].iloc[i-1]) if i > 0 else close_price
# [디버그] 데이터 길이:
# 전체 데이터: 3502
# 실제 시작일 데이터: 3481
# 차이(df_length): 21
#
# 총 3,502개의 데이터 준비 완료
#
# 기존 전략 백테스트 수행 중...
# <ipython-input-5-c070036ad75d>:105: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   final_value = funds + (holdings * float(df['Close'].iloc[start_idx + simulation_period]))
# 기존 전략 결과:
# 최종 수익률: 437.93%
# 최종 자산: $537,928.54
# 총 거래 수: 3456
# 성공 거래 비율: 73.84%
#
# 머신러닝 모델 준비 중...
# Error processing trade 2: datetime.date(2011, 1, 4)
# Error processing trade 1: datetime.date(2011, 1, 3)
# Error processing trade 3: datetime.date(2011, 1, 5)
# Error processing trade 14: datetime.date(2011, 1, 21)
# Error processing trade 19: datetime.date(2011, 1, 28)
# Error processing trade 4: datetime.date(2011, 1, 6)
# Error processing trade 5: datetime.date(2011, 1, 7)
# Error processing trade 6: datetime.date(2011, 1, 10)
# Error processing trade 7: datetime.date(2011, 1, 11)
# Error processing trade 13: datetime.date(2011, 1, 20)
# Error processing trade 20: datetime.date(2011, 1, 31)
# Error processing trade 15: datetime.date(2011, 1, 24)
# Error processing trade 8: datetime.date(2011, 1, 12)
# Error processing trade 9: datetime.date(2011, 1, 13)
# Error processing trade 12: datetime.date(2011, 1, 19)
# Error processing trade 16: datetime.date(2011, 1, 25)
# Error processing trade 17: datetime.date(2011, 1, 26)
# Error processing trade 22: datetime.date(2011, 2, 2)
# Error processing trade 10: datetime.date(2011, 1, 14)
# Error processing trade 11: datetime.date(2011, 1, 18)
# Error processing trade 18: datetime.date(2011, 1, 27)
# Error processing trade 21: datetime.date(2011, 2, 1)
# Error processing trade 23: datetime.date(2011, 2, 3)
# Error processing trade 24: datetime.date(2011, 2, 4)
# Error processing trade 25: datetime.date(2011, 2, 7)
# Error processing trade 26: datetime.date(2011, 2, 8)
# Error processing trade 27: datetime.date(2011, 2, 9)
# Error processing trade 28: datetime.date(2011, 2, 10)
# Error processing trade 51: datetime.date(2011, 3, 16)
# Error processing trade 52: datetime.date(2011, 3, 17)
# Error processing trade 53: datetime.date(2011, 3, 18)
# Error processing trade 29: datetime.date(2011, 2, 11)
# Error processing trade 30: datetime.date(2011, 2, 14)
# Error processing trade 31: datetime.date(2011, 2, 15)
# Error processing trade 32: datetime.date(2011, 2, 16)
# Error processing trade 33: datetime.date(2011, 2, 17)
# Error processing trade 50: datetime.date(2011, 3, 15)
# Error processing trade 54: datetime.date(2011, 3, 21)
# Error processing trade 55: datetime.date(2011, 3, 22)
# Error processing trade 34: datetime.date(2011, 2, 18)
# Error processing trade 35: datetime.date(2011, 2, 22)
# Error processing trade 36: datetime.date(2011, 2, 23)
# Error processing trade 37: datetime.date(2011, 2, 24)
# Error processing trade 38: datetime.date(2011, 2, 25)
# Error processing trade 39: datetime.date(2011, 2, 28)
# Error processing trade 40: datetime.date(2011, 3, 1)
# Error processing trade 41: datetime.date(2011, 3, 2)
# Error processing trade 42: datetime.date(2011, 3, 3)
# Error processing trade 43: datetime.date(2011, 3, 4)
# Error processing trade 44: datetime.date(2011, 3, 7)
# Error processing trade 45: datetime.date(2011, 3, 8)
# Error processing trade 46: datetime.date(2011, 3, 9)
# Error processing trade 47: datetime.date(2011, 3, 10)
# Error processing trade 56: datetime.date(2011, 3, 23)
# Error processing trade 48: datetime.date(2011, 3, 11)
# Error processing trade 49: datetime.date(2011, 3, 14)
# Error processing trade 70: datetime.date(2011, 4, 12)
# Error processing trade 74: datetime.date(2011, 4, 18)
# Error processing trade 57: datetime.date(2011, 3, 24)
# Error processing trade 58: datetime.date(2011, 3, 25)
# Error processing trade 59: datetime.date(2011, 3, 28)
# Error processing trade 68: datetime.date(2011, 4, 8)
# Error processing trade 69: datetime.date(2011, 4, 11)
# Error processing trade 71: datetime.date(2011, 4, 13)
# Error processing trade 72: datetime.date(2011, 4, 14)
# Error processing trade 73: datetime.date(2011, 4, 15)
# Error processing trade 75: datetime.date(2011, 4, 19)
# Error processing trade 60: datetime.date(2011, 3, 29)
# Error processing trade 61: datetime.date(2011, 3, 30)
# Error processing trade 64: datetime.date(2011, 4, 4)
# Error processing trade 65: datetime.date(2011, 4, 5)
# Error processing trade 66: datetime.date(2011, 4, 6)
# Error processing trade 67: datetime.date(2011, 4, 7)
# Error processing trade 62: datetime.date(2011, 3, 31)
# Error processing trade 63: datetime.date(2011, 4, 1)
# Error processing trade 76: datetime.date(2011, 4, 20)
# Error processing trade 77: datetime.date(2011, 4, 21)
# Error processing trade 78: datetime.date(2011, 4, 25)
# Error processing trade 79: datetime.date(2011, 4, 26)
# Error processing trade 80: datetime.date(2011, 4, 27)
# Error processing trade 81: datetime.date(2011, 4, 28)
# Error processing trade 82: datetime.date(2011, 4, 29)
# Error processing trade 83: datetime.date(2011, 5, 2)
# Error processing trade 84: datetime.date(2011, 5, 3)
# Error processing trade 85: datetime.date(2011, 5, 4)
# Error processing trade 86: datetime.date(2011, 5, 5)
# Error processing trade 87: datetime.date(2011, 5, 6)
# Error processing trade 88: datetime.date(2011, 5, 9)
# Error processing trade 89: datetime.date(2011, 5, 10)
# Error processing trade 90: datetime.date(2011, 5, 11)
# Error processing trade 91: datetime.date(2011, 5, 12)
# Error processing trade 92: datetime.date(2011, 5, 13)
# Error processing trade 93: datetime.date(2011, 5, 16)
# Error processing trade 94: datetime.date(2011, 5, 17)
# Error processing trade 115: datetime.date(2011, 6, 16)
# Error processing trade 116: datetime.date(2011, 6, 17)
# Error processing trade 117: datetime.date(2011, 6, 20)
# Error processing trade 95: datetime.date(2011, 5, 18)
# Error processing trade 111: datetime.date(2011, 6, 10)
# Error processing trade 112: datetime.date(2011, 6, 13)
# Error processing trade 114: datetime.date(2011, 6, 15)
# Error processing trade 121: datetime.date(2011, 6, 24)
# Error processing trade 96: datetime.date(2011, 5, 19)
# Error processing trade 113: datetime.date(2011, 6, 14)
# Error processing trade 118: datetime.date(2011, 6, 21)
# Error processing trade 119: datetime.date(2011, 6, 22)
# Error processing trade 122: datetime.date(2011, 6, 27)
# Error processing trade 97: datetime.date(2011, 5, 20)
# Error processing trade 107: datetime.date(2011, 6, 6)
# Error processing trade 108: datetime.date(2011, 6, 7)
# Error processing trade 109: datetime.date(2011, 6, 8)
# Error processing trade 110: datetime.date(2011, 6, 9)
# Error processing trade 120: datetime.date(2011, 6, 23)
# Error processing trade 123: datetime.date(2011, 6, 28)
# Error processing trade 98: datetime.date(2011, 5, 23)
# Error processing trade 99: datetime.date(2011, 5, 24)
# Error processing trade 106: datetime.date(2011, 6, 3)
# Error processing trade 124: datetime.date(2011, 6, 29)
# Error processing trade 100: datetime.date(2011, 5, 25)
# Error processing trade 101: datetime.date(2011, 5, 26)
# Error processing trade 104: datetime.date(2011, 6, 1)
# Error processing trade 105: datetime.date(2011, 6, 2)
# Error processing trade 125: datetime.date(2011, 6, 30)
# Error processing trade 102: datetime.date(2011, 5, 27)
# Error processing trade 103: datetime.date(2011, 5, 31)
# Error processing trade 132: datetime.date(2011, 7, 12)
# Error processing trade 134: datetime.date(2011, 7, 14)
# Error processing trade 136: datetime.date(2011, 7, 18)
# Error processing trade 151: datetime.date(2011, 8, 8)
# Error processing trade 153: datetime.date(2011, 8, 10)
# Error processing trade 126: datetime.date(2011, 7, 1)
# Error processing trade 127: datetime.date(2011, 7, 5)
# Error processing trade 128: datetime.date(2011, 7, 6)
# Error processing trade 129: datetime.date(2011, 7, 7)
# Error processing trade 130: datetime.date(2011, 7, 8)
# Error processing trade 131: datetime.date(2011, 7, 11)
# Error processing trade 133: datetime.date(2011, 7, 13)
# Error processing trade 160: datetime.date(2011, 8, 19)
# Error processing trade 161: datetime.date(2011, 8, 22)
# Error processing trade 135: datetime.date(2011, 7, 15)
# Error processing trade 159: datetime.date(2011, 8, 18)
# Error processing trade 137: datetime.date(2011, 7, 19)
# Error processing trade 162: datetime.date(2011, 8, 23)
# Error processing trade 163: datetime.date(2011, 8, 24)
# Error processing trade 164: datetime.date(2011, 8, 25)
# Error processing trade 138: datetime.date(2011, 7, 20)
# Error processing trade 165: datetime.date(2011, 8, 26)
# Error processing trade 139: datetime.date(2011, 7, 21)
# Error processing trade 140: datetime.date(2011, 7, 22)
# Error processing trade 141: datetime.date(2011, 7, 25)
# Error processing trade 142: datetime.date(2011, 7, 26)
# Error processing trade 143: datetime.date(2011, 7, 27)
# Error processing trade 144: datetime.date(2011, 7, 28)
# Error processing trade 145: datetime.date(2011, 7, 29)
# Error processing trade 146: datetime.date(2011, 8, 1)
# Error processing trade 147: datetime.date(2011, 8, 2)
# Error processing trade 148: datetime.date(2011, 8, 3)
# Error processing trade 170: datetime.date(2011, 9, 2)
# Error processing trade 171: datetime.date(2011, 9, 6)
# Error processing trade 174: datetime.date(2011, 9, 9)
# Error processing trade 149: datetime.date(2011, 8, 4)
# Error processing trade 152: datetime.date(2011, 8, 9)
# Error processing trade 154: datetime.date(2011, 8, 11)
# Error processing trade 155: datetime.date(2011, 8, 12)
# Error processing trade 157: datetime.date(2011, 8, 16)
# Error processing trade 158: datetime.date(2011, 8, 17)
# Error processing trade 173: datetime.date(2011, 9, 8)
# Error processing trade 175: datetime.date(2011, 9, 12)
# Error processing trade 176: datetime.date(2011, 9, 13)
# Error processing trade 150: datetime.date(2011, 8, 5)
# Error processing trade 166: datetime.date(2011, 8, 29)
# Error processing trade 169: datetime.date(2011, 9, 1)
# Error processing trade 172: datetime.date(2011, 9, 7)
# Error processing trade 156: datetime.date(2011, 8, 15)
# Error processing trade 190: datetime.date(2011, 10, 3)
# Error processing trade 191: datetime.date(2011, 10, 4)
# Error processing trade 183: datetime.date(2011, 9, 22)
# Error processing trade 188: datetime.date(2011, 9, 29)
# Error processing trade 189: datetime.date(2011, 9, 30)
# Error processing trade 192: datetime.date(2011, 10, 5)
# Error processing trade 194: datetime.date(2011, 10, 7)
# Error processing trade 167: datetime.date(2011, 8, 30)
# Error processing trade 184: datetime.date(2011, 9, 23)
# Error processing trade 193: datetime.date(2011, 10, 6)
# Error processing trade 168: datetime.date(2011, 8, 31)
# Error processing trade 187: datetime.date(2011, 9, 28)
# Error processing trade 185: datetime.date(2011, 9, 26)
# Error processing trade 177: datetime.date(2011, 9, 14)
# Error processing trade 182: datetime.date(2011, 9, 21)
# Error processing trade 186: datetime.date(2011, 9, 27)
# Error processing trade 195: datetime.date(2011, 10, 10)
# Error processing trade 196: datetime.date(2011, 10, 11)
# Error processing trade 178: datetime.date(2011, 9, 15)
# Error processing trade 197: datetime.date(2011, 10, 12)
# Error processing trade 203: datetime.date(2011, 10, 20)
# Error processing trade 179: datetime.date(2011, 9, 16)
# Error processing trade 181: datetime.date(2011, 9, 20)
# Error processing trade 202: datetime.date(2011, 10, 19)
# Error processing trade 180: datetime.date(2011, 9, 19)
# Error processing trade 211: datetime.date(2011, 11, 1)
# Error processing trade 212: datetime.date(2011, 11, 2)
# Error processing trade 198: datetime.date(2011, 10, 13)
# Error processing trade 199: datetime.date(2011, 10, 14)
# Error processing trade 200: datetime.date(2011, 10, 17)
# Error processing trade 201: datetime.date(2011, 10, 18)
# Error processing trade 225: datetime.date(2011, 11, 21)
# Error processing trade 226: datetime.date(2011, 11, 22)
# Error processing trade 227: datetime.date(2011, 11, 23)
# Error processing trade 228: datetime.date(2011, 11, 25)
# Error processing trade 230: datetime.date(2011, 11, 29)
# Error processing trade 229: datetime.date(2011, 11, 28)
# Error processing trade 204: datetime.date(2011, 10, 21)
# Error processing trade 205: datetime.date(2011, 10, 24)
# Error processing trade 206: datetime.date(2011, 10, 25)
# Error processing trade 207: datetime.date(2011, 10, 26)
# Error processing trade 208: datetime.date(2011, 10, 27)
# Error processing trade 209: datetime.date(2011, 10, 28)
# Error processing trade 210: datetime.date(2011, 10, 31)
# Error processing trade 213: datetime.date(2011, 11, 3)
# Error processing trade 214: datetime.date(2011, 11, 4)
# Error processing trade 215: datetime.date(2011, 11, 7)
# Error processing trade 216: datetime.date(2011, 11, 8)
# Error processing trade 217: datetime.date(2011, 11, 9)
# Error processing trade 218: datetime.date(2011, 11, 10)
# Error processing trade 219: datetime.date(2011, 11, 11)
# Error processing trade 244: datetime.date(2011, 12, 19)
# Error processing trade 220: datetime.date(2011, 11, 14)
# Error processing trade 221: datetime.date(2011, 11, 15)
# Error processing trade 222: datetime.date(2011, 11, 16)
# Error processing trade 223: datetime.date(2011, 11, 17)
# Error processing trade 224: datetime.date(2011, 11, 18)
# Error processing trade 241: datetime.date(2011, 12, 14)
# Error processing trade 242: datetime.date(2011, 12, 15)
# Error processing trade 243: datetime.date(2011, 12, 16)
# Error processing trade 246: datetime.date(2011, 12, 21)
# Error processing trade 240: datetime.date(2011, 12, 13)
# Error processing trade 247: datetime.date(2011, 12, 22)
# Error processing trade 250: datetime.date(2011, 12, 28)
# Error processing trade 245: datetime.date(2011, 12, 20)
# Error processing trade 251: datetime.date(2011, 12, 29)
# Error processing trade 252: datetime.date(2011, 12, 30)
# Error processing trade 237: datetime.date(2011, 12, 8)
# Error processing trade 248: datetime.date(2011, 12, 23)
# Error processing trade 249: datetime.date(2011, 12, 27)
# Error processing trade 231: datetime.date(2011, 11, 30)
# Error processing trade 239: datetime.date(2011, 12, 12)
# Error processing trade 232: datetime.date(2011, 12, 1)
# Error processing trade 233: datetime.date(2011, 12, 2)
# Error processing trade 234: datetime.date(2011, 12, 5)
# Error processing trade 235: datetime.date(2011, 12, 6)
# Error processing trade 236: datetime.date(2011, 12, 7)
# Error processing trade 238: datetime.date(2011, 12, 9)
# Error processing trade 253: datetime.date(2012, 1, 3)
# Error processing trade 254: datetime.date(2012, 1, 4)
# Error processing trade 255: datetime.date(2012, 1, 5)
# Error processing trade 256: datetime.date(2012, 1, 6)
# Error processing trade 257: datetime.date(2012, 1, 9)
# Error processing trade 258: datetime.date(2012, 1, 10)
# Error processing trade 259: datetime.date(2012, 1, 11)
# Error processing trade 261: datetime.date(2012, 1, 13)
# Error processing trade 260: datetime.date(2012, 1, 12)
# Error processing trade 262: datetime.date(2012, 1, 17)
# Error processing trade 263: datetime.date(2012, 1, 18)
# Error processing trade 264: datetime.date(2012, 1, 19)
# Error processing trade 265: datetime.date(2012, 1, 20)
# Error processing trade 266: datetime.date(2012, 1, 23)
# Error processing trade 267: datetime.date(2012, 1, 24)
# Error processing trade 268: datetime.date(2012, 1, 25)
# Error processing trade 269: datetime.date(2012, 1, 26)
# Error processing trade 270: datetime.date(2012, 1, 27)
# Error processing trade 271: datetime.date(2012, 1, 30)
# Error processing trade 272: datetime.date(2012, 1, 31)
# Error processing trade 273: datetime.date(2012, 2, 1)
# Error processing trade 274: datetime.date(2012, 2, 2)
# Error processing trade 275: datetime.date(2012, 2, 3)
# Error processing trade 276: datetime.date(2012, 2, 6)
# Error processing trade 277: datetime.date(2012, 2, 7)
# Error processing trade 278: datetime.date(2012, 2, 8)
# Error processing trade 280: datetime.date(2012, 2, 10)
# Error processing trade 283: datetime.date(2012, 2, 15)
# Error processing trade 279: datetime.date(2012, 2, 9)
# Error processing trade 281: datetime.date(2012, 2, 13)
# Error processing trade 282: datetime.date(2012, 2, 14)
# Error processing trade 284: datetime.date(2012, 2, 16)
# Error processing trade 285: datetime.date(2012, 2, 17)
# Error processing trade 286: datetime.date(2012, 2, 21)
# Error processing trade 287: datetime.date(2012, 2, 22)
# Error processing trade 288: datetime.date(2012, 2, 23)
# Error processing trade 289: datetime.date(2012, 2, 24)
# Error processing trade 290: datetime.date(2012, 2, 27)
# Error processing trade 296: datetime.date(2012, 3, 6)
# Error processing trade 297: datetime.date(2012, 3, 7)
# Error processing trade 292: datetime.date(2012, 2, 29)
# Error processing trade 295: datetime.date(2012, 3, 5)
# Error processing trade 291: datetime.date(2012, 2, 28)
# Error processing trade 294: datetime.date(2012, 3, 2)
# Error processing trade 298: datetime.date(2012, 3, 8)
# Error processing trade 293: datetime.date(2012, 3, 1)
# Error processing trade 299: datetime.date(2012, 3, 9)
# Error processing trade 300: datetime.date(2012, 3, 12)
# Error processing trade 301: datetime.date(2012, 3, 13)
# Error processing trade 302: datetime.date(2012, 3, 14)
# Error processing trade 303: datetime.date(2012, 3, 15)
# Error processing trade 330: datetime.date(2012, 4, 24)
# Error processing trade 304: datetime.date(2012, 3, 16)
# Error processing trade 305: datetime.date(2012, 3, 19)
# Error processing trade 306: datetime.date(2012, 3, 20)
# Error processing trade 307: datetime.date(2012, 3, 21)
# Error processing trade 308: datetime.date(2012, 3, 22)
# Error processing trade 309: datetime.date(2012, 3, 23)
# Error processing trade 310: datetime.date(2012, 3, 26)
# Error processing trade 311: datetime.date(2012, 3, 27)
# Error processing trade 312: datetime.date(2012, 3, 28)
# Error processing trade 313: datetime.date(2012, 3, 29)
# Error processing trade 314: datetime.date(2012, 3, 30)
# Error processing trade 315: datetime.date(2012, 4, 2)
# Error processing trade 316: datetime.date(2012, 4, 3)
# Error processing trade 317: datetime.date(2012, 4, 4)
# Error processing trade 318: datetime.date(2012, 4, 5)
# Error processing trade 319: datetime.date(2012, 4, 9)
# Error processing trade 320: datetime.date(2012, 4, 10)
# Error processing trade 321: datetime.date(2012, 4, 11)
# Error processing trade 322: datetime.date(2012, 4, 12)
# Error processing trade 323: datetime.date(2012, 4, 13)
# Error processing trade 324: datetime.date(2012, 4, 16)
# Error processing trade 325: datetime.date(2012, 4, 17)
# Error processing trade 326: datetime.date(2012, 4, 18)
# Error processing trade 327: datetime.date(2012, 4, 19)
# Error processing trade 328: datetime.date(2012, 4, 20)
# Error processing trade 329: datetime.date(2012, 4, 23)
# Error processing trade 331: datetime.date(2012, 4, 25)
# Error processing trade 357: datetime.date(2012, 6, 1)
# Error processing trade 332: datetime.date(2012, 4, 26)
# Error processing trade 333: datetime.date(2012, 4, 27)
# Error processing trade 358: datetime.date(2012, 6, 4)
# Error processing trade 334: datetime.date(2012, 4, 30)
# Error processing trade 335: datetime.date(2012, 5, 1)
# Error processing trade 336: datetime.date(2012, 5, 2)
# Error processing trade 337: datetime.date(2012, 5, 3)
# Error processing trade 338: datetime.date(2012, 5, 4)
# Error processing trade 339: datetime.date(2012, 5, 7)
# Error processing trade 348: datetime.date(2012, 5, 18)
# Error processing trade 359: datetime.date(2012, 6, 5)
# Error processing trade 340: datetime.date(2012, 5, 8)
# Error processing trade 347: datetime.date(2012, 5, 17)
# Error processing trade 353: datetime.date(2012, 5, 25)
# Error processing trade 356: datetime.date(2012, 5, 31)
# Error processing trade 363: datetime.date(2012, 6, 11)
# Error processing trade 365: datetime.date(2012, 6, 13)
# Error processing trade 341: datetime.date(2012, 5, 9)
# Error processing trade 352: datetime.date(2012, 5, 24)
# Error processing trade 355: datetime.date(2012, 5, 30)
# Error processing trade 361: datetime.date(2012, 6, 7)
# Error processing trade 366: datetime.date(2012, 6, 14)
# Error processing trade 342: datetime.date(2012, 5, 10)
# Error processing trade 343: datetime.date(2012, 5, 11)
# Error processing trade 344: datetime.date(2012, 5, 14)
# Error processing trade 345: datetime.date(2012, 5, 15)
# Error processing trade 346: datetime.date(2012, 5, 16)
# Error processing trade 349: datetime.date(2012, 5, 21)
# Error processing trade 373: datetime.date(2012, 6, 25)
# Error processing trade 376: datetime.date(2012, 6, 28)
# Error processing trade 350: datetime.date(2012, 5, 22)
# Error processing trade 351: datetime.date(2012, 5, 23)
# Error processing trade 360: datetime.date(2012, 6, 6)
# Error processing trade 362: datetime.date(2012, 6, 8)
# Error processing trade 364: datetime.date(2012, 6, 12)
# Error processing trade 371: datetime.date(2012, 6, 21)
# Error processing trade 374: datetime.date(2012, 6, 26)
# Error processing trade 375: datetime.date(2012, 6, 27)
# Error processing trade 354: datetime.date(2012, 5, 29)
# Error processing trade 385: datetime.date(2012, 7, 12)
# Error processing trade 367: datetime.date(2012, 6, 15)
# Error processing trade 394: datetime.date(2012, 7, 25)
# Error processing trade 368: datetime.date(2012, 6, 18)
# Error processing trade 369: datetime.date(2012, 6, 19)
# Error processing trade 370: datetime.date(2012, 6, 20)
# Error processing trade 372: datetime.date(2012, 6, 22)
# Error processing trade 383: datetime.date(2012, 7, 10)
# Error processing trade 384: datetime.date(2012, 7, 11)
# Error processing trade 386: datetime.date(2012, 7, 13)
# Error processing trade 387: datetime.date(2012, 7, 16)
# Error processing trade 392: datetime.date(2012, 7, 23)
# Error processing trade 393: datetime.date(2012, 7, 24)
# Error processing trade 395: datetime.date(2012, 7, 26)
# Error processing trade 388: datetime.date(2012, 7, 17)
# Error processing trade 377: datetime.date(2012, 6, 29)
# Error processing trade 378: datetime.date(2012, 7, 2)
# Error processing trade 381: datetime.date(2012, 7, 6)
# Error processing trade 382: datetime.date(2012, 7, 9)
# Error processing trade 389: datetime.date(2012, 7, 18)
# Error processing trade 391: datetime.date(2012, 7, 20)
# Error processing trade 399: datetime.date(2012, 8, 1)
# Error processing trade 400: datetime.date(2012, 8, 2)
# Error processing trade 397: datetime.date(2012, 7, 30)
# Error processing trade 396: datetime.date(2012, 7, 27)
# Error processing trade 398: datetime.date(2012, 7, 31)
# Error processing trade 379: datetime.date(2012, 7, 3)
# Error processing trade 380: datetime.date(2012, 7, 5)
# Error processing trade 390: datetime.date(2012, 7, 19)
# Error processing trade 401: datetime.date(2012, 8, 3)
# Error processing trade 402: datetime.date(2012, 8, 6)
# Error processing trade 403: datetime.date(2012, 8, 7)
# Error processing trade 404: datetime.date(2012, 8, 8)
# Error processing trade 405: datetime.date(2012, 8, 9)
# Error processing trade 406: datetime.date(2012, 8, 10)
# Error processing trade 407: datetime.date(2012, 8, 13)
# Error processing trade 408: datetime.date(2012, 8, 14)
# Error processing trade 409: datetime.date(2012, 8, 15)
# Error processing trade 420: datetime.date(2012, 8, 30)
# Error processing trade 415: datetime.date(2012, 8, 23)
# Error processing trade 410: datetime.date(2012, 8, 16)
# Error processing trade 422: datetime.date(2012, 9, 4)
# Error processing trade 423: datetime.date(2012, 9, 5)
# Error processing trade 411: datetime.date(2012, 8, 17)
# Error processing trade 412: datetime.date(2012, 8, 20)
# Error processing trade 413: datetime.date(2012, 8, 21)
# Error processing trade 414: datetime.date(2012, 8, 22)
# Error processing trade 416: datetime.date(2012, 8, 24)
# Error processing trade 417: datetime.date(2012, 8, 27)
# Error processing trade 418: datetime.date(2012, 8, 28)
# Error processing trade 419: datetime.date(2012, 8, 29)
# Error processing trade 421: datetime.date(2012, 8, 31)
# Error processing trade 424: datetime.date(2012, 9, 6)
# Error processing trade 425: datetime.date(2012, 9, 7)
# Error processing trade 426: datetime.date(2012, 9, 10)
# Error processing trade 427: datetime.date(2012, 9, 11)
# Error processing trade 428: datetime.date(2012, 9, 12)
# Error processing trade 429: datetime.date(2012, 9, 13)
# Error processing trade 430: datetime.date(2012, 9, 14)
# Error processing trade 431: datetime.date(2012, 9, 17)
# Error processing trade 432: datetime.date(2012, 9, 18)
# Error processing trade 433: datetime.date(2012, 9, 19)
# Error processing trade 434: datetime.date(2012, 9, 20)
# Error processing trade 435: datetime.date(2012, 9, 21)
# Error processing trade 436: datetime.date(2012, 9, 24)
# Error processing trade 437: datetime.date(2012, 9, 25)
# Error processing trade 438: datetime.date(2012, 9, 26)
# Error processing trade 439: datetime.date(2012, 9, 27)
# Error processing trade 440: datetime.date(2012, 9, 28)
# Error processing trade 441: datetime.date(2012, 10, 1)
# Error processing trade 442: datetime.date(2012, 10, 2)
# Error processing trade 443: datetime.date(2012, 10, 3)
# Error processing trade 444: datetime.date(2012, 10, 4)
# Error processing trade 445: datetime.date(2012, 10, 5)
# Error processing trade 446: datetime.date(2012, 10, 8)
# Error processing trade 447: datetime.date(2012, 10, 9)
# Error processing trade 448: datetime.date(2012, 10, 10)
# Error processing trade 471: datetime.date(2012, 11, 14)
# Error processing trade 472: datetime.date(2012, 11, 15)
# Error processing trade 473: datetime.date(2012, 11, 16)
# Error processing trade 449: datetime.date(2012, 10, 11)
# Error processing trade 470: datetime.date(2012, 11, 13)
# Error processing trade 450: datetime.date(2012, 10, 12)
# Error processing trade 451: datetime.date(2012, 10, 15)
# Error processing trade 467: datetime.date(2012, 11, 8)
# Error processing trade 468: datetime.date(2012, 11, 9)
# Error processing trade 469: datetime.date(2012, 11, 12)
# Error processing trade 452: datetime.date(2012, 10, 16)
# Error processing trade 474: datetime.date(2012, 11, 19)
# Error processing trade 475: datetime.date(2012, 11, 20)
# Error processing trade 453: datetime.date(2012, 10, 17)
# Error processing trade 454: datetime.date(2012, 10, 18)
# Error processing trade 455: datetime.date(2012, 10, 19)
# Error processing trade 456: datetime.date(2012, 10, 22)
# Error processing trade 457: datetime.date(2012, 10, 23)
# Error processing trade 458: datetime.date(2012, 10, 24)
# Error processing trade 459: datetime.date(2012, 10, 25)
# Error processing trade 460: datetime.date(2012, 10, 26)
# Error processing trade 461: datetime.date(2012, 10, 31)
# Error processing trade 462: datetime.date(2012, 11, 1)
# Error processing trade 463: datetime.date(2012, 11, 2)
# Error processing trade 464: datetime.date(2012, 11, 5)
# Error processing trade 465: datetime.date(2012, 11, 6)
# Error processing trade 466: datetime.date(2012, 11, 7)
# Error processing trade 476: datetime.date(2012, 11, 21)
# Error processing trade 477: datetime.date(2012, 11, 23)
# Error processing trade 478: datetime.date(2012, 11, 26)
# Error processing trade 479: datetime.date(2012, 11, 27)
# Error processing trade 485: datetime.date(2012, 12, 5)
# Error processing trade 486: datetime.date(2012, 12, 6)
# Error processing trade 487: datetime.date(2012, 12, 7)
# Error processing trade 488: datetime.date(2012, 12, 10)
# Error processing trade 491: datetime.date(2012, 12, 13)
# Error processing trade 492: datetime.date(2012, 12, 14)
# Error processing trade 498: datetime.date(2012, 12, 24)
# Error processing trade 499: datetime.date(2012, 12, 26)
# Error processing trade 500: datetime.date(2012, 12, 27)
# Error processing trade 501: datetime.date(2012, 12, 28)
# Error processing trade 480: datetime.date(2012, 11, 28)
# Error processing trade 481: datetime.date(2012, 11, 29)
# Error processing trade 482: datetime.date(2012, 11, 30)
# Error processing trade 483: datetime.date(2012, 12, 3)
# Error processing trade 484: datetime.date(2012, 12, 4)
# Error processing trade 493: datetime.date(2012, 12, 17)
# Error processing trade 497: datetime.date(2012, 12, 21)
# Error processing trade 502: datetime.date(2012, 12, 31)
# Error processing trade 489: datetime.date(2012, 12, 11)
# Error processing trade 490: datetime.date(2012, 12, 12)
# Error processing trade 494: datetime.date(2012, 12, 18)
# Error processing trade 495: datetime.date(2012, 12, 19)
# Error processing trade 496: datetime.date(2012, 12, 20)
# Error processing trade 503: datetime.date(2013, 1, 2)
# Error processing trade 504: datetime.date(2013, 1, 3)
# Error processing trade 505: datetime.date(2013, 1, 4)
# Error processing trade 506: datetime.date(2013, 1, 7)
# Error processing trade 507: datetime.date(2013, 1, 8)
# Error processing trade 508: datetime.date(2013, 1, 9)
# Error processing trade 509: datetime.date(2013, 1, 10)
# Error processing trade 510: datetime.date(2013, 1, 11)
# Error processing trade 511: datetime.date(2013, 1, 14)
# Error processing trade 512: datetime.date(2013, 1, 15)
# Error processing trade 513: datetime.date(2013, 1, 16)
# Error processing trade 514: datetime.date(2013, 1, 17)
# Error processing trade 515: datetime.date(2013, 1, 18)
# Error processing trade 516: datetime.date(2013, 1, 22)
# Error processing trade 537: datetime.date(2013, 2, 21)
# Error processing trade 539: datetime.date(2013, 2, 25)
# Error processing trade 517: datetime.date(2013, 1, 23)
# Error processing trade 518: datetime.date(2013, 1, 24)
# Error processing trade 519: datetime.date(2013, 1, 25)
# Error processing trade 520: datetime.date(2013, 1, 28)
# Error processing trade 525: datetime.date(2013, 2, 4)
# Error processing trade 540: datetime.date(2013, 2, 26)
# Error processing trade 521: datetime.date(2013, 1, 29)
# Error processing trade 522: datetime.date(2013, 1, 30)
# Error processing trade 523: datetime.date(2013, 1, 31)
# Error processing trade 524: datetime.date(2013, 2, 1)
# Error processing trade 526: datetime.date(2013, 2, 5)
# Error processing trade 527: datetime.date(2013, 2, 6)
# Error processing trade 528: datetime.date(2013, 2, 7)
# Error processing trade 529: datetime.date(2013, 2, 8)
# Error processing trade 530: datetime.date(2013, 2, 11)
# Error processing trade 531: datetime.date(2013, 2, 12)
# Error processing trade 532: datetime.date(2013, 2, 13)
# Error processing trade 533: datetime.date(2013, 2, 14)
# Error processing trade 534: datetime.date(2013, 2, 15)
# Error processing trade 535: datetime.date(2013, 2, 19)
# Error processing trade 536: datetime.date(2013, 2, 20)
# Error processing trade 538: datetime.date(2013, 2, 22)
# Error processing trade 541: datetime.date(2013, 2, 27)
# Error processing trade 542: datetime.date(2013, 2, 28)
# Error processing trade 543: datetime.date(2013, 3, 1)
# Error processing trade 544: datetime.date(2013, 3, 4)
# Error processing trade 545: datetime.date(2013, 3, 5)
# Error processing trade 546: datetime.date(2013, 3, 6)
# Error processing trade 547: datetime.date(2013, 3, 7)
# Error processing trade 548: datetime.date(2013, 3, 8)
# Error processing trade 549: datetime.date(2013, 3, 11)
# Error processing trade 550: datetime.date(2013, 3, 12)
# Error processing trade 576: datetime.date(2013, 4, 18)
# Error processing trade 551: datetime.date(2013, 3, 13)
# Error processing trade 552: datetime.date(2013, 3, 14)
# Error processing trade 553: datetime.date(2013, 3, 15)
# Error processing trade 554: datetime.date(2013, 3, 18)
# Error processing trade 555: datetime.date(2013, 3, 19)
# Error processing trade 557: datetime.date(2013, 3, 21)
# Error processing trade 567: datetime.date(2013, 4, 5)
# Error processing trade 568: datetime.date(2013, 4, 8)
# Error processing trade 575: datetime.date(2013, 4, 17)
# Error processing trade 577: datetime.date(2013, 4, 19)
# Error processing trade 556: datetime.date(2013, 3, 20)
# Error processing trade 558: datetime.date(2013, 3, 22)
# Error processing trade 559: datetime.date(2013, 3, 25)
# Error processing trade 560: datetime.date(2013, 3, 26)
# Error processing trade 561: datetime.date(2013, 3, 27)
# Error processing trade 563: datetime.date(2013, 4, 1)
# Error processing trade 565: datetime.date(2013, 4, 3)
# Error processing trade 566: datetime.date(2013, 4, 4)
# Error processing trade 569: datetime.date(2013, 4, 9)
# Error processing trade 573: datetime.date(2013, 4, 15)
# Error processing trade 578: datetime.date(2013, 4, 22)
# Error processing trade 562: datetime.date(2013, 3, 28)
# Error processing trade 564: datetime.date(2013, 4, 2)
# Error processing trade 574: datetime.date(2013, 4, 16)
# Error processing trade 579: datetime.date(2013, 4, 23)
# Error processing trade 580: datetime.date(2013, 4, 24)
# Error processing trade 582: datetime.date(2013, 4, 26)
# Error processing trade 571: datetime.date(2013, 4, 11)
# Error processing trade 572: datetime.date(2013, 4, 12)
# Error processing trade 581: datetime.date(2013, 4, 25)
# Error processing trade 570: datetime.date(2013, 4, 10)
# Error processing trade 583: datetime.date(2013, 4, 29)
# Error processing trade 585: datetime.date(2013, 5, 1)
# Error processing trade 584: datetime.date(2013, 4, 30)
# Error processing trade 586: datetime.date(2013, 5, 2)
# Error processing trade 587: datetime.date(2013, 5, 3)
# Error processing trade 588: datetime.date(2013, 5, 6)
# Error processing trade 589: datetime.date(2013, 5, 7)
# Error processing trade 590: datetime.date(2013, 5, 8)
# Error processing trade 591: datetime.date(2013, 5, 9)
# Error processing trade 592: datetime.date(2013, 5, 10)
# Error processing trade 593: datetime.date(2013, 5, 13)
# Error processing trade 594: datetime.date(2013, 5, 14)
# Error processing trade 595: datetime.date(2013, 5, 15)
# Error processing trade 596: datetime.date(2013, 5, 16)
# Error processing trade 597: datetime.date(2013, 5, 17)
# Error processing trade 598: datetime.date(2013, 5, 20)
# Error processing trade 599: datetime.date(2013, 5, 21)
# Error processing trade 600: datetime.date(2013, 5, 22)
# Error processing trade 601: datetime.date(2013, 5, 23)
# Error processing trade 622: datetime.date(2013, 6, 24)
# Error processing trade 602: datetime.date(2013, 5, 24)
# Error processing trade 623: datetime.date(2013, 6, 25)
# Error processing trade 603: datetime.date(2013, 5, 28)
# Error processing trade 620: datetime.date(2013, 6, 20)
# Error processing trade 621: datetime.date(2013, 6, 21)
# Error processing trade 624: datetime.date(2013, 6, 26)
# Error processing trade 604: datetime.date(2013, 5, 29)
# Error processing trade 625: datetime.date(2013, 6, 27)
# Error processing trade 626: datetime.date(2013, 6, 28)
# Error processing trade 605: datetime.date(2013, 5, 30)
# Error processing trade 609: datetime.date(2013, 6, 5)
# Error processing trade 610: datetime.date(2013, 6, 6)
# Error processing trade 613: datetime.date(2013, 6, 11)
# Error processing trade 614: datetime.date(2013, 6, 12)
# Error processing trade 615: datetime.date(2013, 6, 13)
# Error processing trade 616: datetime.date(2013, 6, 14)
# Error processing trade 619: datetime.date(2013, 6, 19)
# Error processing trade 627: datetime.date(2013, 7, 1)
# Error processing trade 628: datetime.date(2013, 7, 2)
# Error processing trade 629: datetime.date(2013, 7, 3)
# Error processing trade 630: datetime.date(2013, 7, 5)
# Error processing trade 631: datetime.date(2013, 7, 8)
# Error processing trade 606: datetime.date(2013, 5, 31)
# Error processing trade 617: datetime.date(2013, 6, 17)
# Error processing trade 607: datetime.date(2013, 6, 3)
# Error processing trade 608: datetime.date(2013, 6, 4)
# Error processing trade 611: datetime.date(2013, 6, 7)
# Error processing trade 612: datetime.date(2013, 6, 10)
# Error processing trade 618: datetime.date(2013, 6, 18)
# Error processing trade 632: datetime.date(2013, 7, 9)
# Error processing trade 633: datetime.date(2013, 7, 10)
# Error processing trade 642: datetime.date(2013, 7, 23)
# Error processing trade 643: datetime.date(2013, 7, 24)
# Error processing trade 640: datetime.date(2013, 7, 19)
# Error processing trade 634: datetime.date(2013, 7, 11)
# Error processing trade 635: datetime.date(2013, 7, 12)
# Error processing trade 636: datetime.date(2013, 7, 15)
# Error processing trade 637: datetime.date(2013, 7, 16)
# Error processing trade 638: datetime.date(2013, 7, 17)
# Error processing trade 639: datetime.date(2013, 7, 18)
# Error processing trade 641: datetime.date(2013, 7, 22)
# Error processing trade 644: datetime.date(2013, 7, 25)
# Error processing trade 645: datetime.date(2013, 7, 26)
# Error processing trade 646: datetime.date(2013, 7, 29)
# Error processing trade 667: datetime.date(2013, 8, 27)
# Error processing trade 647: datetime.date(2013, 7, 30)
# Error processing trade 659: datetime.date(2013, 8, 15)
# Error processing trade 660: datetime.date(2013, 8, 16)
# Error processing trade 661: datetime.date(2013, 8, 19)
# Error processing trade 662: datetime.date(2013, 8, 20)
# Error processing trade 663: datetime.date(2013, 8, 21)
# Error processing trade 668: datetime.date(2013, 8, 28)
# Error processing trade 670: datetime.date(2013, 8, 30)
# Error processing trade 648: datetime.date(2013, 7, 31)
# Error processing trade 649: datetime.date(2013, 8, 1)
# Error processing trade 650: datetime.date(2013, 8, 2)
# Error processing trade 651: datetime.date(2013, 8, 5)
# Error processing trade 652: datetime.date(2013, 8, 6)
# Error processing trade 669: datetime.date(2013, 8, 29)
# Error processing trade 671: datetime.date(2013, 9, 3)
# Error processing trade 653: datetime.date(2013, 8, 7)
# Error processing trade 655: datetime.date(2013, 8, 9)
# Error processing trade 664: datetime.date(2013, 8, 22)
# Error processing trade 672: datetime.date(2013, 9, 4)
# Error processing trade 654: datetime.date(2013, 8, 8)
# Error processing trade 656: datetime.date(2013, 8, 12)
# Error processing trade 665: datetime.date(2013, 8, 23)
# Error processing trade 666: datetime.date(2013, 8, 26)
# Error processing trade 673: datetime.date(2013, 9, 5)
# Error processing trade 657: datetime.date(2013, 8, 13)
# Error processing trade 658: datetime.date(2013, 8, 14)
# Error processing trade 674: datetime.date(2013, 9, 6)
# Error processing trade 697: datetime.date(2013, 10, 9)
# Error processing trade 675: datetime.date(2013, 9, 9)
# Error processing trade 680: datetime.date(2013, 9, 16)
# Error processing trade 696: datetime.date(2013, 10, 8)
# Error processing trade 676: datetime.date(2013, 9, 10)
# Error processing trade 677: datetime.date(2013, 9, 11)
# Error processing trade 678: datetime.date(2013, 9, 12)
# Error processing trade 679: datetime.date(2013, 9, 13)
# Error processing trade 681: datetime.date(2013, 9, 17)
# Error processing trade 682: datetime.date(2013, 9, 18)
# Error processing trade 683: datetime.date(2013, 9, 19)
# Error processing trade 684: datetime.date(2013, 9, 20)
# Error processing trade 685: datetime.date(2013, 9, 23)
# Error processing trade 686: datetime.date(2013, 9, 24)
# Error processing trade 687: datetime.date(2013, 9, 25)
# Error processing trade 688: datetime.date(2013, 9, 26)
# Error processing trade 689: datetime.date(2013, 9, 27)
# Error processing trade 690: datetime.date(2013, 9, 30)
# Error processing trade 693: datetime.date(2013, 10, 3)
# Error processing trade 694: datetime.date(2013, 10, 4)
# Error processing trade 695: datetime.date(2013, 10, 7)
# Error processing trade 698: datetime.date(2013, 10, 10)
# Error processing trade 699: datetime.date(2013, 10, 11)
# Error processing trade 701: datetime.date(2013, 10, 15)
# Error processing trade 691: datetime.date(2013, 10, 1)
# Error processing trade 692: datetime.date(2013, 10, 2)
# Error processing trade 700: datetime.date(2013, 10, 14)
# Error processing trade 702: datetime.date(2013, 10, 16)
# Error processing trade 703: datetime.date(2013, 10, 17)
# Error processing trade 718: datetime.date(2013, 11, 7)
# Error processing trade 704: datetime.date(2013, 10, 18)
# Error processing trade 705: datetime.date(2013, 10, 21)
# Error processing trade 706: datetime.date(2013, 10, 22)
# Error processing trade 707: datetime.date(2013, 10, 23)
# Error processing trade 708: datetime.date(2013, 10, 24)
# Error processing trade 720: datetime.date(2013, 11, 11)
# Error processing trade 709: datetime.date(2013, 10, 25)
# Error processing trade 710: datetime.date(2013, 10, 28)
# Error processing trade 713: datetime.date(2013, 10, 31)
# Error processing trade 714: datetime.date(2013, 11, 1)
# Error processing trade 715: datetime.date(2013, 11, 4)
# Error processing trade 719: datetime.date(2013, 11, 8)
# Error processing trade 721: datetime.date(2013, 11, 12)
# Error processing trade 726: datetime.date(2013, 11, 19)
# Error processing trade 727: datetime.date(2013, 11, 20)
# Error processing trade 711: datetime.date(2013, 10, 29)
# Error processing trade 712: datetime.date(2013, 10, 30)
# Error processing trade 716: datetime.date(2013, 11, 5)
# Error processing trade 717: datetime.date(2013, 11, 6)
# Error processing trade 725: datetime.date(2013, 11, 18)
# Error processing trade 722: datetime.date(2013, 11, 13)
# Error processing trade 728: datetime.date(2013, 11, 21)
# Error processing trade 723: datetime.date(2013, 11, 14)
# Error processing trade 724: datetime.date(2013, 11, 15)
# Error processing trade 729: datetime.date(2013, 11, 22)
# Error processing trade 730: datetime.date(2013, 11, 25)
# Error processing trade 731: datetime.date(2013, 11, 26)
# Error processing trade 743: datetime.date(2013, 12, 13)
# Error processing trade 741: datetime.date(2013, 12, 11)
# Error processing trade 742: datetime.date(2013, 12, 12)
# Error processing trade 745: datetime.date(2013, 12, 17)
# Error processing trade 732: datetime.date(2013, 11, 27)
# Error processing trade 735: datetime.date(2013, 12, 3)
# Error processing trade 737: datetime.date(2013, 12, 5)
# Error processing trade 744: datetime.date(2013, 12, 16)
# Error processing trade 733: datetime.date(2013, 11, 29)
# Error processing trade 734: datetime.date(2013, 12, 2)
# Error processing trade 736: datetime.date(2013, 12, 4)
# Error processing trade 738: datetime.date(2013, 12, 6)
# Error processing trade 747: datetime.date(2013, 12, 19)
# Error processing trade 739: datetime.date(2013, 12, 9)
# Error processing trade 740: datetime.date(2013, 12, 10)
# Error processing trade 746: datetime.date(2013, 12, 18)
# Error processing trade 748: datetime.date(2013, 12, 20)
# Error processing trade 749: datetime.date(2013, 12, 23)
# Error processing trade 750: datetime.date(2013, 12, 24)
# Error processing trade 751: datetime.date(2013, 12, 26)
# Error processing trade 776: datetime.date(2014, 2, 3)
# Error processing trade 752: datetime.date(2013, 12, 27)
# Error processing trade 778: datetime.date(2014, 2, 5)
# Error processing trade 753: datetime.date(2013, 12, 30)
# Error processing trade 771: datetime.date(2014, 1, 27)
# Error processing trade 772: datetime.date(2014, 1, 28)
# Error processing trade 773: datetime.date(2014, 1, 29)
# Error processing trade 777: datetime.date(2014, 2, 4)
# Error processing trade 779: datetime.date(2014, 2, 6)
# Error processing trade 754: datetime.date(2013, 12, 31)
# Error processing trade 755: datetime.date(2014, 1, 2)
# Error processing trade 757: datetime.date(2014, 1, 6)
# Error processing trade 762: datetime.date(2014, 1, 13)
# Error processing trade 770: datetime.date(2014, 1, 24)
# Error processing trade 774: datetime.date(2014, 1, 30)
# Error processing trade 775: datetime.date(2014, 1, 31)
# Error processing trade 756: datetime.date(2014, 1, 3)
# Error processing trade 760: datetime.date(2014, 1, 9)
# Error processing trade 780: datetime.date(2014, 2, 7)
# Error processing trade 758: datetime.date(2014, 1, 7)
# Error processing trade 759: datetime.date(2014, 1, 8)
# Error processing trade 761: datetime.date(2014, 1, 10)
# Error processing trade 763: datetime.date(2014, 1, 14)
# Error processing trade 764: datetime.date(2014, 1, 15)
# Error processing trade 781: datetime.date(2014, 2, 10)
# Error processing trade 765: datetime.date(2014, 1, 16)
# Error processing trade 766: datetime.date(2014, 1, 17)
# Error processing trade 767: datetime.date(2014, 1, 21)
# Error processing trade 768: datetime.date(2014, 1, 22)
# Error processing trade 769: datetime.date(2014, 1, 23)
# Error processing trade 782: datetime.date(2014, 2, 11)
# Error processing trade 783: datetime.date(2014, 2, 12)
# Error processing trade 784: datetime.date(2014, 2, 13)
# Error processing trade 785: datetime.date(2014, 2, 14)
# Error processing trade 786: datetime.date(2014, 2, 18)
# Error processing trade 787: datetime.date(2014, 2, 19)
# Error processing trade 788: datetime.date(2014, 2, 20)
# Error processing trade 789: datetime.date(2014, 2, 21)
# Error processing trade 790: datetime.date(2014, 2, 24)
# Error processing trade 791: datetime.date(2014, 2, 25)
# Error processing trade 792: datetime.date(2014, 2, 26)
# Error processing trade 793: datetime.date(2014, 2, 27)
# Error processing trade 794: datetime.date(2014, 2, 28)
# Error processing trade 795: datetime.date(2014, 3, 3)
# Error processing trade 796: datetime.date(2014, 3, 4)
# Error processing trade 797: datetime.date(2014, 3, 5)
# Error processing trade 798: datetime.date(2014, 3, 6)
# Error processing trade 799: datetime.date(2014, 3, 7)
# Error processing trade 800: datetime.date(2014, 3, 10)
# Error processing trade 801: datetime.date(2014, 3, 11)
# Error processing trade 824: datetime.date(2014, 4, 11)
# Error processing trade 825: datetime.date(2014, 4, 14)
# Error processing trade 802: datetime.date(2014, 3, 12)
# Error processing trade 803: datetime.date(2014, 3, 13)
# Error processing trade 804: datetime.date(2014, 3, 14)
# Error processing trade 805: datetime.date(2014, 3, 17)
# Error processing trade 806: datetime.date(2014, 3, 18)
# Error processing trade 807: datetime.date(2014, 3, 19)
# Error processing trade 808: datetime.date(2014, 3, 20)
# Error processing trade 809: datetime.date(2014, 3, 21)
# Error processing trade 810: datetime.date(2014, 3, 24)
# Error processing trade 811: datetime.date(2014, 3, 25)
# Error processing trade 812: datetime.date(2014, 3, 26)
# Error processing trade 813: datetime.date(2014, 3, 27)
# Error processing trade 814: datetime.date(2014, 3, 28)
# Error processing trade 815: datetime.date(2014, 3, 31)
# Error processing trade 823: datetime.date(2014, 4, 10)
# Error processing trade 826: datetime.date(2014, 4, 15)
# Error processing trade 816: datetime.date(2014, 4, 1)
# Error processing trade 817: datetime.date(2014, 4, 2)
# Error processing trade 818: datetime.date(2014, 4, 3)
# Error processing trade 819: datetime.date(2014, 4, 4)
# Error processing trade 820: datetime.date(2014, 4, 7)
# Error processing trade 821: datetime.date(2014, 4, 8)
# Error processing trade 822: datetime.date(2014, 4, 9)
# Error processing trade 827: datetime.date(2014, 4, 16)
# Error processing trade 828: datetime.date(2014, 4, 17)
# Error processing trade 833: datetime.date(2014, 4, 25)
# Error processing trade 829: datetime.date(2014, 4, 21)
# Error processing trade 831: datetime.date(2014, 4, 23)
# Error processing trade 834: datetime.date(2014, 4, 28)
# Error processing trade 840: datetime.date(2014, 5, 6)
# Error processing trade 841: datetime.date(2014, 5, 7)
# Error processing trade 842: datetime.date(2014, 5, 8)
# Error processing trade 843: datetime.date(2014, 5, 9)
# Error processing trade 830: datetime.date(2014, 4, 22)
# Error processing trade 832: datetime.date(2014, 4, 24)
# Error processing trade 835: datetime.date(2014, 4, 29)
# Error processing trade 836: datetime.date(2014, 4, 30)
# Error processing trade 837: datetime.date(2014, 5, 1)
# Error processing trade 838: datetime.date(2014, 5, 2)
# ...
# Error processing trade 3206: datetime.date(2023, 9, 28)
# Error processing trade 3207: datetime.date(2023, 9, 29)
# Error processing trade 3211: datetime.date(2023, 10, 5)
# Error processing trade 3187: datetime.date(2023, 8, 31)
# Error processing trade 3188: datetime.date(2023, 9, 1)
# Error processing trade 3189: datetime.date(2023, 9, 5)
# Error processing trade 3190: datetime.date(2023, 9, 6)
# Error processing trade 3191: datetime.date(2023, 9, 7)
# Error processing trade 3192: datetime.date(2023, 9, 8)
# Error processing trade 3193: datetime.date(2023, 9, 11)
# Error processing trade 3194: datetime.date(2023, 9, 12)
# Error processing trade 3195: datetime.date(2023, 9, 13)
# Error processing trade 3196: datetime.date(2023, 9, 14)
# Error processing trade 3197: datetime.date(2023, 9, 15)
# Error processing trade 3198: datetime.date(2023, 9, 18)
# Error processing trade 3199: datetime.date(2023, 9, 19)
# Error processing trade 3200: datetime.date(2023, 9, 20)
# Error processing trade 3226: datetime.date(2023, 10, 26)
# Error processing trade 3227: datetime.date(2023, 10, 27)
# Error processing trade 3225: datetime.date(2023, 10, 25)
# Error processing trade 3228: datetime.date(2023, 10, 30)
# Error processing trade 3229: datetime.date(2023, 10, 31)
# Error processing trade 3203: datetime.date(2023, 9, 25)
# Error processing trade 3222: datetime.date(2023, 10, 20)
# Error processing trade 3223: datetime.date(2023, 10, 23)
# Error processing trade 3230: datetime.date(2023, 11, 1)
# Error processing trade 3224: datetime.date(2023, 10, 24)
# Error processing trade 3208: datetime.date(2023, 10, 2)
# Error processing trade 3210: datetime.date(2023, 10, 4)
# Error processing trade 3220: datetime.date(2023, 10, 18)
# Error processing trade 3221: datetime.date(2023, 10, 19)
# Error processing trade 3231: datetime.date(2023, 11, 2)
# Error processing trade 3212: datetime.date(2023, 10, 6)
# Error processing trade 3213: datetime.date(2023, 10, 9)
# Error processing trade 3214: datetime.date(2023, 10, 10)
# Error processing trade 3216: datetime.date(2023, 10, 12)
# Error processing trade 3217: datetime.date(2023, 10, 13)
# Error processing trade 3218: datetime.date(2023, 10, 16)
# Error processing trade 3219: datetime.date(2023, 10, 17)
# Error processing trade 3232: datetime.date(2023, 11, 3)
# Error processing trade 3233: datetime.date(2023, 11, 6)
# Error processing trade 3236: datetime.date(2023, 11, 9)
# Error processing trade 3234: datetime.date(2023, 11, 7)
# Error processing trade 3235: datetime.date(2023, 11, 8)
# Error processing trade 3215: datetime.date(2023, 10, 11)
# Error processing trade 3238: datetime.date(2023, 11, 13)
# Error processing trade 3237: datetime.date(2023, 11, 10)
# Error processing trade 3254: datetime.date(2023, 12, 6)
# Error processing trade 3239: datetime.date(2023, 11, 14)
# Error processing trade 3240: datetime.date(2023, 11, 15)
# Error processing trade 3241: datetime.date(2023, 11, 16)
# Error processing trade 3242: datetime.date(2023, 11, 17)
# Error processing trade 3244: datetime.date(2023, 11, 21)
# Error processing trade 3246: datetime.date(2023, 11, 24)
# Error processing trade 3247: datetime.date(2023, 11, 27)
# Error processing trade 3249: datetime.date(2023, 11, 29)
# Error processing trade 3250: datetime.date(2023, 11, 30)
# Error processing trade 3251: datetime.date(2023, 12, 1)
# Error processing trade 3252: datetime.date(2023, 12, 4)
# Error processing trade 3253: datetime.date(2023, 12, 5)
# Error processing trade 3255: datetime.date(2023, 12, 7)
# Error processing trade 3243: datetime.date(2023, 11, 20)
# Error processing trade 3245: datetime.date(2023, 11, 22)
# Error processing trade 3248: datetime.date(2023, 11, 28)
# Error processing trade 3256: datetime.date(2023, 12, 8)
# Error processing trade 3257: datetime.date(2023, 12, 11)
# Error processing trade 3272: datetime.date(2024, 1, 3)
# Error processing trade 3273: datetime.date(2024, 1, 4)
# Error processing trade 3274: datetime.date(2024, 1, 5)
# Error processing trade 3258: datetime.date(2023, 12, 12)
# Error processing trade 3259: datetime.date(2023, 12, 13)
# Error processing trade 3260: datetime.date(2023, 12, 14)
# Error processing trade 3261: datetime.date(2023, 12, 15)
# Error processing trade 3264: datetime.date(2023, 12, 20)
# Error processing trade 3271: datetime.date(2024, 1, 2)
# Error processing trade 3275: datetime.date(2024, 1, 8)
# Error processing trade 3276: datetime.date(2024, 1, 9)
# Error processing trade 3281: datetime.date(2024, 1, 17)
# Error processing trade 3262: datetime.date(2023, 12, 18)
# Error processing trade 3265: datetime.date(2023, 12, 21)
# Error processing trade 3266: datetime.date(2023, 12, 22)
# Error processing trade 3277: datetime.date(2024, 1, 10)
# Error processing trade 3278: datetime.date(2024, 1, 11)
# Error processing trade 3279: datetime.date(2024, 1, 12)
# Error processing trade 3280: datetime.date(2024, 1, 16)
# Error processing trade 3263: datetime.date(2023, 12, 19)
# Error processing trade 3270: datetime.date(2023, 12, 29)
# Error processing trade 3267: datetime.date(2023, 12, 26)
# Error processing trade 3268: datetime.date(2023, 12, 27)
# Error processing trade 3269: datetime.date(2023, 12, 28)
# Error processing trade 3282: datetime.date(2024, 1, 18)
# Error processing trade 3291: datetime.date(2024, 1, 31)
# Error processing trade 3283: datetime.date(2024, 1, 19)
# Error processing trade 3284: datetime.date(2024, 1, 22)
# Error processing trade 3292: datetime.date(2024, 2, 1)
# Error processing trade 3285: datetime.date(2024, 1, 23)
# Error processing trade 3286: datetime.date(2024, 1, 24)
# Error processing trade 3287: datetime.date(2024, 1, 25)
# Error processing trade 3288: datetime.date(2024, 1, 26)
# Error processing trade 3289: datetime.date(2024, 1, 29)
# Error processing trade 3290: datetime.date(2024, 1, 30)
# Error processing trade 3293: datetime.date(2024, 2, 2)
# Error processing trade 3294: datetime.date(2024, 2, 5)
# Error processing trade 3295: datetime.date(2024, 2, 6)
# Error processing trade 3300: datetime.date(2024, 2, 13)
# Error processing trade 3304: datetime.date(2024, 2, 20)
# Error processing trade 3305: datetime.date(2024, 2, 21)
# Error processing trade 3296: datetime.date(2024, 2, 7)
# Error processing trade 3297: datetime.date(2024, 2, 8)
# Error processing trade 3298: datetime.date(2024, 2, 9)
# Error processing trade 3299: datetime.date(2024, 2, 12)
# Error processing trade 3301: datetime.date(2024, 2, 14)
# Error processing trade 3302: datetime.date(2024, 2, 15)
# Error processing trade 3303: datetime.date(2024, 2, 16)
# Error processing trade 3306: datetime.date(2024, 2, 22)
# Error processing trade 3307: datetime.date(2024, 2, 23)
# Error processing trade 3308: datetime.date(2024, 2, 26)
# Error processing trade 3309: datetime.date(2024, 2, 27)
# Error processing trade 3310: datetime.date(2024, 2, 28)
# Error processing trade 3311: datetime.date(2024, 2, 29)
# Error processing trade 3312: datetime.date(2024, 3, 1)
# Error processing trade 3313: datetime.date(2024, 3, 4)
# Error processing trade 3314: datetime.date(2024, 3, 5)
# Error processing trade 3315: datetime.date(2024, 3, 6)
# Error processing trade 3316: datetime.date(2024, 3, 7)
# Error processing trade 3317: datetime.date(2024, 3, 8)
# Error processing trade 3318: datetime.date(2024, 3, 11)
# Error processing trade 3319: datetime.date(2024, 3, 12)
# Error processing trade 3320: datetime.date(2024, 3, 13)
# Error processing trade 3321: datetime.date(2024, 3, 14)
# Error processing trade 3322: datetime.date(2024, 3, 15)
# Error processing trade 3346: datetime.date(2024, 4, 19)
# Error processing trade 3323: datetime.date(2024, 3, 18)
# Error processing trade 3324: datetime.date(2024, 3, 19)
# Error processing trade 3325: datetime.date(2024, 3, 20)
# Error processing trade 3326: datetime.date(2024, 3, 21)
# Error processing trade 3327: datetime.date(2024, 3, 22)
# Error processing trade 3347: datetime.date(2024, 4, 22)
# Error processing trade 3328: datetime.date(2024, 3, 25)
# Error processing trade 3345: datetime.date(2024, 4, 18)
# Error processing trade 3348: datetime.date(2024, 4, 23)
# Error processing trade 3350: datetime.date(2024, 4, 25)
# Error processing trade 3353: datetime.date(2024, 4, 30)
# Error processing trade 3354: datetime.date(2024, 5, 1)
# Error processing trade 3329: datetime.date(2024, 3, 26)
# Error processing trade 3330: datetime.date(2024, 3, 27)
# Error processing trade 3331: datetime.date(2024, 3, 28)
# Error processing trade 3332: datetime.date(2024, 4, 1)
# Error processing trade 3344: datetime.date(2024, 4, 17)
# Error processing trade 3349: datetime.date(2024, 4, 24)
# Error processing trade 3355: datetime.date(2024, 5, 2)
# Error processing trade 3333: datetime.date(2024, 4, 2)
# Error processing trade 3334: datetime.date(2024, 4, 3)
# Error processing trade 3335: datetime.date(2024, 4, 4)
# Error processing trade 3342: datetime.date(2024, 4, 15)
# Error processing trade 3343: datetime.date(2024, 4, 16)
# Error processing trade 3351: datetime.date(2024, 4, 26)
# Error processing trade 3352: datetime.date(2024, 4, 29)
# Error processing trade 3356: datetime.date(2024, 5, 3)
# Error processing trade 3336: datetime.date(2024, 4, 5)
# Error processing trade 3337: datetime.date(2024, 4, 8)
# Error processing trade 3338: datetime.date(2024, 4, 9)
# Error processing trade 3339: datetime.date(2024, 4, 10)
# Error processing trade 3357: datetime.date(2024, 5, 6)
# Error processing trade 3358: datetime.date(2024, 5, 7)
# Error processing trade 3359: datetime.date(2024, 5, 8)
# Error processing trade 3340: datetime.date(2024, 4, 11)
# Error processing trade 3341: datetime.date(2024, 4, 12)
# Error processing trade 3360: datetime.date(2024, 5, 9)
# Error processing trade 3361: datetime.date(2024, 5, 10)
# Error processing trade 3362: datetime.date(2024, 5, 13)
# Error processing trade 3363: datetime.date(2024, 5, 14)
# Error processing trade 3374: datetime.date(2024, 5, 30)
# Error processing trade 3375: datetime.date(2024, 5, 31)
# Error processing trade 3364: datetime.date(2024, 5, 15)
# Error processing trade 3365: datetime.date(2024, 5, 16)
# Error processing trade 3366: datetime.date(2024, 5, 17)
# Error processing trade 3367: datetime.date(2024, 5, 20)
# Error processing trade 3368: datetime.date(2024, 5, 21)
# Error processing trade 3369: datetime.date(2024, 5, 22)
# Error processing trade 3370: datetime.date(2024, 5, 23)
# Error processing trade 3371: datetime.date(2024, 5, 24)
# Error processing trade 3373: datetime.date(2024, 5, 29)
# Error processing trade 3376: datetime.date(2024, 6, 3)
# Error processing trade 3377: datetime.date(2024, 6, 4)
# Error processing trade 3372: datetime.date(2024, 5, 28)
# Error processing trade 3379: datetime.date(2024, 6, 6)
# Error processing trade 3380: datetime.date(2024, 6, 7)
# Error processing trade 3378: datetime.date(2024, 6, 5)
# Error processing trade 3381: datetime.date(2024, 6, 10)
# Error processing trade 3382: datetime.date(2024, 6, 11)
# Error processing trade 3383: datetime.date(2024, 6, 12)
# Error processing trade 3390: datetime.date(2024, 6, 24)
# Error processing trade 3384: datetime.date(2024, 6, 13)
# Error processing trade 3385: datetime.date(2024, 6, 14)
# Error processing trade 3394: datetime.date(2024, 6, 28)
# Error processing trade 3389: datetime.date(2024, 6, 21)
# Error processing trade 3391: datetime.date(2024, 6, 25)
# Error processing trade 3392: datetime.date(2024, 6, 26)
# Error processing trade 3386: datetime.date(2024, 6, 17)
# Error processing trade 3387: datetime.date(2024, 6, 18)
# Error processing trade 3388: datetime.date(2024, 6, 20)
# Error processing trade 3393: datetime.date(2024, 6, 27)
# Error processing trade 3395: datetime.date(2024, 7, 1)
# Error processing trade 3421: datetime.date(2024, 8, 7)
# Error processing trade 3419: datetime.date(2024, 8, 5)
# Error processing trade 3396: datetime.date(2024, 7, 2)
# Error processing trade 3420: datetime.date(2024, 8, 6)
# Error processing trade 3397: datetime.date(2024, 7, 3)
# Error processing trade 3398: datetime.date(2024, 7, 5)
# Error processing trade 3418: datetime.date(2024, 8, 2)
# Error processing trade 3422: datetime.date(2024, 8, 8)
# Error processing trade 3423: datetime.date(2024, 8, 9)
# Error processing trade 3424: datetime.date(2024, 8, 12)
# Error processing trade 3399: datetime.date(2024, 7, 8)
# Error processing trade 3400: datetime.date(2024, 7, 9)
# Error processing trade 3412: datetime.date(2024, 7, 25)
# Error processing trade 3415: datetime.date(2024, 7, 30)
# Error processing trade 3417: datetime.date(2024, 8, 1)
# Error processing trade 3425: datetime.date(2024, 8, 13)
# Error processing trade 3426: datetime.date(2024, 8, 14)
# Error processing trade 3401: datetime.date(2024, 7, 10)
# Error processing trade 3402: datetime.date(2024, 7, 11)
# Error processing trade 3413: datetime.date(2024, 7, 26)
# Error processing trade 3403: datetime.date(2024, 7, 12)
# Error processing trade 3404: datetime.date(2024, 7, 15)
# Error processing trade 3405: datetime.date(2024, 7, 16)
# Error processing trade 3406: datetime.date(2024, 7, 17)
# Error processing trade 3407: datetime.date(2024, 7, 18)
# Error processing trade 3408: datetime.date(2024, 7, 19)
# Error processing trade 3409: datetime.date(2024, 7, 22)
# Error processing trade 3410: datetime.date(2024, 7, 23)
# Error processing trade 3411: datetime.date(2024, 7, 24)
# Error processing trade 3414: datetime.date(2024, 7, 29)
# Error processing trade 3416: datetime.date(2024, 7, 31)
# Error processing trade 3442: datetime.date(2024, 9, 6)
# Error processing trade 3443: datetime.date(2024, 9, 9)
# Error processing trade 3444: datetime.date(2024, 9, 10)
# Error processing trade 3439: datetime.date(2024, 9, 3)
# Error processing trade 3440: datetime.date(2024, 9, 4)
# Error processing trade 3441: datetime.date(2024, 9, 5)
# Error processing trade 3445: datetime.date(2024, 9, 11)
# Error processing trade 3427: datetime.date(2024, 8, 15)
# Error processing trade 3437: datetime.date(2024, 8, 29)
# Error processing trade 3446: datetime.date(2024, 9, 12)
# Error processing trade 3448: datetime.date(2024, 9, 16)
# Error processing trade 3449: datetime.date(2024, 9, 17)
# Error processing trade 3450: datetime.date(2024, 9, 18)
# Error processing trade 3428: datetime.date(2024, 8, 16)
# Error processing trade 3429: datetime.date(2024, 8, 19)
# Error processing trade 3430: datetime.date(2024, 8, 20)
# Error processing trade 3431: datetime.date(2024, 8, 21)
# Error processing trade 3432: datetime.date(2024, 8, 22)
# Error processing trade 3433: datetime.date(2024, 8, 23)
# Error processing trade 3434: datetime.date(2024, 8, 26)
# Error processing trade 3435: datetime.date(2024, 8, 27)
# Error processing trade 3436: datetime.date(2024, 8, 28)
# Error processing trade 3447: datetime.date(2024, 9, 13)
# Error processing trade 3438: datetime.date(2024, 8, 30)
# Error processing trade 3459: datetime.date(2024, 10, 1)
# Error processing trade 3460: datetime.date(2024, 10, 2)
# Error processing trade 3461: datetime.date(2024, 10, 3)
# Error processing trade 3463: datetime.date(2024, 10, 7)
# Error processing trade 3451: datetime.date(2024, 9, 19)
# Error processing trade 3452: datetime.date(2024, 9, 20)
# 오류 발생: "None of [Index(['MACD', 'MACD_Hist', 'MA50이격도', 'MA200이격도', '수익률_5', '수익률_60', 'ATR',\n       'BB_Width', '변동성_20', '거래량_증감', '거래량_비율', '가격위치_20', '가격위치_60', '캔들크기',\n       '연속상승', 'RSI'],\n      dtype='object')] are in the [columns]"
#
# [디버그] 상세 오류:
# Traceback (most recent call last):
#   File "<ipython-input-8-b895b258c635>", line 78, in <cell line: 1>
#     X_train = df_train[feature_columns]
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 4108, in __getitem__
#     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 6200, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 6249, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['MACD', 'MACD_Hist', 'MA50이격도', 'MA200이격도', '수익률_5', '수익률_60', 'ATR',\n       'BB_Width', '변동성_20', '거래량_증감', '거래량_비율', '가격위치_20', '가격위치_60', '캔들크기',\n       '연속상승', 'RSI'],\n      dtype='object')] are in the [columns]"
